# %% [markdown]
# <a href="https://colab.research.google.com/github/aasturiasg/COMP-593-Repository/blob/main/Lab-3-starting-with-databases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB 3: WORKING WITH DATABASES

# %% [markdown]
# ## Introduction
#
# During this lab, we will experiment with using a few different libararies and modules to connect to and interact with an SQLite database. After creating and configuring our testing database, we will populate it with Fake data and run some queries to see what kind of information we can retreive. For context, we will be creating RSSN, the "Really Simple Social Network".

# %% [markdown]
# ## Creating a SQLite Database
#
# We will be utilizing the `sqlite3` library to create our database file, as it offers the convienience of creating our database file automatically in the event that it cannot find an existing file at the path specified.
#
# **Before you run the below code:**
# On the left of the notebook, select the file folder icon. Then, after you run the code block, you should be able to observe the creation of the database file. If it doesn't appear, try clicking the "Refresh" button above the list of folders.

# %%
import sqlite3

#When we retreive a Connection object, a new database will be created for us if it doesn't already exist. 
myConnection = sqlite3.connect('social_network.db')
print(sqlite3.version)
# Out:
# 2.6.0

# %% [markdown]
# ## Creating a Table

# %% [markdown]
# We'll use the below code to create a table called `people` within our database.

# %%
import sqlite3

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first table:
createPeopleTable = """ CREATE TABLE IF NOT EXISTS people (
                          id integer PRIMARY KEY,
                          name text NOT NULL,
                          email text NOT NULL,
                          address text NOT NULL,
                          city text NOT NULL,
                          province text NOT NULL,
                          country text NOT NULL,
                          phone text,
                          bio text,
                          dob date NOT NULL,
                          heatmap integer,
                          created_at datetime NOT NULL,
                          updated_at datetime NOT NULL,
                          ipv4 text
                        );"""

#Now that we have the string to create our table,
#Cursor objects have an execute() method which will accept an SQL string and perform the operations described.

myCursor.execute(createPeopleTable)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT group_concat(name, ', ') FROM pragma_table_info('people')")
print(myCursor.fetchone())

#We use to the commit() method on the database Connection object to persist our changes
myConnection.commit()

#It is always a good idea to close a connection when it will no longer be used
myConnection.close()
# Out:
# ('id, name, email, address, city, province, country, phone, bio, dob, heatmap, created_at, updated_at, ipv4',)

# %% [markdown]
# If you received a tuple containing the names of the columns, awesome! We have successfully created our database table.
# ```
# ('id, name, email, address, city, province, country, phone, bio, created_at, updated_at',)
# ```
#
# Run the below code block to add our first entry.

# %%
import sqlite3
from pprint import pprint #Outputs data in a slightly easier to read format
from datetime import datetime #For generating dates and times

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first entry:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

"""
The ?'s are placeholders that we can fill in when we use the execute() method.
This is really handy for code reuse, as we can pass those values are variables in a tuple
Instead of hard coding them into the statement.
"""

myPerson = ("John Doe", 
            "johndoe@anon.null", 
            "123 Fake St.", 
            "Fakesville", 
            "Fakesdom", 
            "Fakopolis", 
            None, 
            None,
            "1967-09-12",
            0,
            datetime.now(), 
            datetime.now(),
            None)

myCursor.execute(addPersonQuery, myPerson)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())

# If you run this code block a few times, you will see that you only have 1 entry,
# If you uncomment the below lines and run the block a few more times, you will begin to see multiple entries.
myConnection.commit()
myConnection.close()
# Out:
# [(1,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2022-02-17 22:15:19.864350',
#   '2022-02-17 22:15:19.864363',
#   None),
#  (2,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2022-02-17 22:15:25.512083',
#   '2022-02-17 22:15:25.512094',
#   None)]

# %% [markdown]
# # Lab Submission

# %% [markdown]
# We're going to build our experience with working with Libraries and examining documentation by populating our 'People' table with data provided to us by the `Faker` library. `Faker` is used to generate fake data and is very helpful for the rapid generation of databases for the purposes of testing. Run the two blocks below to install faker and get an idea of what it can do.

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-13.0.0-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 31.8 MB/s
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /usr/local/lib/python3.7/dist-packages (from faker) (3.10.0.2)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.7/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.4->faker) (1.15.0)
# Installing collected packages: faker
# Successfully installed faker-13.0.0

# %%
from faker import Faker

fake = Faker()

for _ in range(10):
  print('{} || {}'.format( fake.name(), fake.job() ) )
# Out:
# Christopher Costa || Dealer
# Gerald Baldwin || Physiological scientist
# Kathy Bailey || Engineer, electrical
# Meredith White || Public affairs consultant
# Victor Jensen || Visual merchandiser
# Rebecca Waters || Surveyor, quantity
# Brenda Lin || Chartered management accountant
# Gregory Hutchinson || Cabin crew
# Lori Cowan || Magazine journalist
# Melissa Harrington || Engineer, aeronautical

# %% [markdown]
# Very cool! Faker has tons of `providers` that can all be used to populate fake data. The [list of providers](https://faker.readthedocs.io/en/stable/providers.html) in the Faker documentation will help you fill out the columns for our People table.
#
# The goal of this script is to populate the people table with 1000 entries, with the following constraints:
#
# 1. The `heatmap` column must contain a random number between `999` and `2500`
# 2. The `created_at` and `updated_at` columns must use the `datetime` object (see examples above)
# 2. Use `Faker` to generate all other fields.
#
# *Hint: Each of the methods contained in the provider can be called directly from the base Faker object, for example, one can call the `file_name()` method from `faker.providers.file` by calling `Faker().file_name()`*

# %%
import sqlite3 #making sqlite3 available for use, to communicate with our database
from faker import Faker #making the class Faker available for use, to generate random data
from datetime import datetime #For generating dates and times
#Don't forget to import the module to generate random numbers!
from random import randint #randint to generate random integer numbers
from pprint import pprint #Outputs data in a slightly easier to read format

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#This is the same syntax as the above example:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

fake = Faker('en_CA') #new instance of a Faker object for getting random data, setting the location to Canada

for i in range(1000):
  #data obtained from faker to be placed on the placeholders of the query
  myPerson = (fake.name(), 
              fake.ascii_email(), 
              fake.street_address(), 
              fake.city(), 
              fake.administrative_unit(), 
              fake.country(), 
              fake.phone_number(), 
              fake.sentence(nb_words=8),
              fake.date_of_birth(),
              randint(999, 2500),
              datetime.now(), 
              datetime.now(),
              fake.ipv4())

  myCursor.execute(addPersonQuery, myPerson) #run query and replace placeholders

myCursor.execute("SELECT * FROM people") #gets all the rows from the database
pprint(myCursor.fetchall()) #shows the results of the last query

myConnection.commit()#applies the changes to the actual database
myConnection.close()#closes the connection

#Ideally, you will want to create a loop that will iterate 1000 times,
#Observe the example in the earlier code block showing the parameter tuple `myPerson`
#You can duplicate that inside your loop and replace those fields with calls to the appropriate faker provider method
#Execute your statement inside the loop,
#But, don't forget to commit and close your connection when you have finished!
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   'United States Minor Outlying Islands',
#   '+1 (934) 300-8215',
#   'Ut minus omnis fugit laudantium totam.',
#   '2002-07-09',
#   1165,
#   '2022-02-17 22:15:41.527679',
#   '2022-02-17 22:15:41.527681',
#   '139.134.199.149'),
#  (649,
#   'Lisa Flowers',
#   'millerangela@yahoo.com',
#   '632 Jones Crest Suite 737',
#   'East Carla',
#   'Alberta',
#   'Trinidad and Tobago',
#   '1 (333) 258-9055',
#   'Sint similique fugit sint voluptas.',
#   '1911-05-18',
#   1289,
#   '2022-02-17 22:15:41.528480',
#   '2022-02-17 22:15:41.528482',
#   '219.55.234.117'),
#  (650,
#   'Michael Ford',
#   'pateljames@cook.com',
#   '1085 Jones Way Apt. 720',
#   'Lake Timothyshire',
#   'Alberta',
#   'Armenia',
#   '(970) 561-3975',
#   'Accusantium nesciunt delectus magnam.',
#   '1916-09-23',
#   1223,
#   '2022-02-17 22:15:41.529387',
#   '2022-02-17 22:15:41.529388',
#   '195.242.16.195'),
#  (651,
#   'Kelsey Strong',
#   'dnguyen@yahoo.com',
#   '053 Julia Hills',
#   'West Michael',
#   'Alberta',
#   'Australia',
#   '+1 (106) 737-8847',
#   'Accusamus nulla est nostrum enim.',
#   '2014-06-22',
#   1301,
#   '2022-02-17 22:15:41.530058',
#   '2022-02-17 22:15:41.530059',
#   '48.35.8.33'),
#  (652,
#   'Matthew Parrish',
#   'lwalker@yahoo.com',
#   '62137 Michael Points Suite 118',
#   'West Elizabethberg',
#   'New Brunswick',
#   'Saint Barthelemy',
#   '1-788-425-9768',
#   'Nihil quod veniam perspiciatis modi labore expedita impedit.',
#   '1979-05-29',
#   1770,
#   '2022-02-17 22:15:41.530811',
#   '2022-02-17 22:15:41.530812',
#   '192.5.213.131'),
#  (653,
#   'Kyle Martin',
#   'mmartinez@hotmail.com',
#   '89166 Obrien Mountains',
#   'South David',
#   'Newfoundland and Labrador',
#   'Oman',
#   '1-291-492-6847',
#   'Possimus vitae veritatis earum est tempore voluptates cum commodi.',
#   '2007-10-09',
#   1414,
#   '2022-02-17 22:15:41.531562',
#   '2022-02-17 22:15:41.531563',
#   '4.87.110.251'),
#  (654,
#   'Gary Johnson',
#   'mcbridemelissa@gmail.com',
#   '6501 Kevin Highway',
#   'North Kristen',
#   'Newfoundland and Labrador',
#   'Norfolk Island',
#   '+1 (194) 782-2062',
#   'Quod molestiae cum beatae.',
#   '1947-05-29',
#   1931,
#   '2022-02-17 22:15:41.532302',
#   '2022-02-17 22:15:41.532303',
#   '33.241.36.74'),
#  (655,
#   'Kerry Pearson',
#   'johnsmith@yahoo.com',
#   '7476 Wheeler Throughway',
#   'West Marilyn',
#   'Ontario',
#   'Korea',
#   '1 (864) 715-9733',
#   'Laborum magni eveniet nam porro.',
#   '1960-03-16',
#   1928,
#   '2022-02-17 22:15:41.533073',
#   '2022-02-17 22:15:41.533075',
#   '217.189.60.230'),
#  (656,
#   'Virginia Velez',
#   'teresa60@hotmail.com',
#   '652 Carr Burgs Apt. 672',
#   'South Michaelbury',
#   'Nunavut',
#   'Micronesia',
#   '128-234-5191',
#   'Quaerat ab autem perspiciatis magni nam recusandae eum.',
#   '1906-12-24',
#   2401,
#   '2022-02-17 22:15:41.533806',
#   '2022-02-17 22:15:41.533807',
#   '182.220.2.139'),
#  (657,
#   'Brian Brooks',
#   'joannaweaver@watson-williams.com',
#   '85451 Walker Manors',
#   'Port Victor',
#   'Nunavut',
#   'Malta',
#   '(305) 801-8433 x218',
#   'Quae soluta repellat incidunt facere odit nulla dolor reiciendis.',
#   '1949-07-31',
#   1219,
#   '2022-02-17 22:15:41.534800',
#   '2022-02-17 22:15:41.534802',
#   '42.161.151.30'),
#  (658,
#   'Ray Roberts',
#   'johnlewis@chung.com',
#   '2943 Brandon Views',
#   'Kelleyfurt',
#   'New Brunswick',
#   'Bhutan',
#   '475-156-7613',
#   'Numquam magnam aliquam exercitationem modi odit adipisci omnis velit ab '
#   'voluptas.',
#   '1976-09-03',
#   2232,
#   '2022-02-17 22:15:41.535831',
#   '2022-02-17 22:15:41.535832',
#   '3.100.31.33'),
#  (659,
#   'Alexandria Gonzales',
#   'patrick76@anderson-webb.com',
#   '932 Troy Forest Apt. 489',
#   'New Stephenton',
#   'Manitoba',
#   'Austria',
#   '679-960-7295 x965',
#   'Doloribus totam autem optio quidem illum.',
#   '2018-08-21',
#   2041,
#   '2022-02-17 22:15:41.536705',
#   '2022-02-17 22:15:41.536707',
#   '79.111.94.219'),
#  (660,
#   'Larry Nelson',
#   'candicehansen@hotmail.com',
#   '793 Christopher Walks Suite 222',
#   'South Ryan',
#   'British Columbia',
#   'Anguilla',
#   '663-047-4047',
#   'Facilis eum esse eius maiores sed officiis explicabo.',
#   '1964-09-07',
#   2178,
#   '2022-02-17 22:15:41.537476',
#   '2022-02-17 22:15:41.537477',
#   '13.134.244.173'),
#  (661,
#   'Sandra Horton',
#   'rushjacqueline@gmail.com',
#   '0507 Michelle Prairie Apt. 196',
#   'Lake Tiffanystad',
#   'Alberta',
#   'Zambia',
#   '+1 (755) 176-8548',
#   'Quae explicabo aspernatur harum excepturi quaerat.',
#   '2021-05-19',
#   1061,
#   '2022-02-17 22:15:41.538237',
#   '2022-02-17 22:15:41.538239',
#   '179.146.155.166'),
#  (662,
#   'Diane Watson',
#   'coopereric@branch.com',
#   '9095 Roberta Lodge',
#   'South Donnaview',
#   'Saskatchewan',
#   'Morocco',
#   '777.765.0904',
#   'Quaerat aspernatur asperiores eveniet a maiores.',
#   '1938-02-22',
#   2277,
#   '2022-02-17 22:15:41.539235',
#   '2022-02-17 22:15:41.539236',
#   '61.194.154.140'),
#  (663,
#   'Darrell Hart',
#   'josephrogers@yahoo.com',
#   '659 Amanda Union Suite 700',
#   'Rickyburgh',
#   'Northwest Territories',
#   'Croatia',
#   '1-790-374-0589',
#   'Commodi quisquam alias sit dolor eligendi.',
#   '1983-04-02',
#   1720,
#   '2022-02-17 22:15:41.539986',
#   '2022-02-17 22:15:41.539988',
#   '54.76.125.95'),
#  (664,
#   'Latoya Mack',
#   'watkinspamela@gallegos.com',
#   '099 Jones Union Suite 095',
#   'Christopherbury',
#   'Saskatchewan',
#   "Cote d'Ivoire",
#   '994-006-6460',
#   'Saepe ipsum quisquam aperiam voluptatem a.',
#   '1923-09-20',
#   2159,
#   '2022-02-17 22:15:41.541027',
#   '2022-02-17 22:15:41.541028',
#   '59.254.198.5'),
#  (665,
#   'Kathy Wilson',
#   'medinaalan@thomas-mckay.org',
#   '161 Robert Street',
#   'Port Brianland',
#   'Yukon Territory',
#   'Panama',
#   '973-669-3680 x847',
#   'Eveniet nesciunt explicabo pariatur magnam doloremque eligendi dicta iste '
#   'dignissimos.',
#   '1969-10-24',
#   2472,
#   '2022-02-17 22:15:41.541956',
#   '2022-02-17 22:15:41.541958',
#   '108.132.213.86'),
#  (666,
#   'Eric Mathis',
#   'hdiaz@miller.com',
#   '097 Luis Prairie',
#   'North Vanessamouth',
#   'British Columbia',
#   'Panama',
#   '1-217-840-5847',
#   'Non temporibus et quae nemo sit perferendis ut ducimus quibusdam rerum.',
#   '1931-10-23',
#   1899,
#   '2022-02-17 22:15:41.542909',
#   '2022-02-17 22:15:41.542910',
#   '14.49.247.51'),
#  (667,
#   'Christina Medina',
#   'victoriageorge@yahoo.com',
#   '2466 Dawson Valley',
#   'East Scottshire',
#   'New Brunswick',
#   'Aruba',
#   '1-454-198-8640',
#   'Voluptates quisquam impedit recusandae iste natus laborum totam.',
#   '2009-07-16',
#   1690,
#   '2022-02-17 22:15:41.543691',
#   '2022-02-17 22:15:41.543693',
#   '106.0.28.195'),
#  (668,
#   'Heather Jones',
#   'juliamiller@gmail.com',
#   '5387 Parker Drive Apt. 637',
#   'West Monica',
#   'Prince Edward Island',
#   'Burundi',
#   '(482) 368-9019 x497',
#   'Aliquam dicta officia veniam voluptatum et consequatur quis.',
#   '1966-02-25',
#   1003,
#   '2022-02-17 22:15:41.544503',
#   '2022-02-17 22:15:41.544505',
#   '46.38.148.35'),
#  (669,
#   'Brian Lopez',
#   'michael83@ramirez.com',
#   '9721 Morgan Plaza',
#   'Lake Stephanieport',
#   'British Columbia',
#   'Luxembourg',
#   '1 (985) 424-0564',
#   'Cupiditate cum recusandae voluptas asperiores in cumque illum eum.',
#   '1922-03-16',
#   2159,
#   '2022-02-17 22:15:41.545434',
#   '2022-02-17 22:15:41.545435',
#   '20.175.64.4'),
#  (670,
#   'Kenneth Ramirez',
#   'randolphandrew@pierce-young.info',
#   '08857 Rebecca Manors Apt. 944',
#   'New Jessica',
#   'Yukon Territory',
#   'United Arab Emirates',
#   '(689) 669-8696 x611',
#   'Commodi veritatis tempora fuga incidunt impedit.',
#   '1911-09-28',
#   1936,
#   '2022-02-17 22:15:41.546392',
#   '2022-02-17 22:15:41.546394',
#   '172.119.74.230'),
#  (671,
#   'Jennifer Perez',
#   'jodichapman@hotmail.com',
#   '39580 Lowe Springs',
#   'Miguelmouth',
#   'Quebec',
#   'Ethiopia',
#   '953-970-7103',
#   'Ea nulla aliquam aut.',
#   '2013-02-08',
#   1154,
#   '2022-02-17 22:15:41.547149',
#   '2022-02-17 22:15:41.547150',
#   '211.59.122.23'),
#  (672,
#   'Deborah Gordon',
#   'jamesmeredith@dorsey.org',
#   '0844 King Brook Suite 492',
#   'North Dustinhaven',
#   'Alberta',
#   'Swaziland',
#   '490-284-2380 x882',
#   'Inventore dolore quia omnis laboriosam accusantium vel.',
#   '1942-11-05',
#   1706,
#   '2022-02-17 22:15:41.548768',
#   '2022-02-17 22:15:41.548770',
#   '192.71.252.241'),
#  (673,
#   'David Campbell',
#   'sgonzalez@patterson-sawyer.com',
#   '581 Mason Gateway',
#   'Sandrastad',
#   'Nunavut',
#   'Albania',
#   '363.178.0178',
#   'Recusandae fugiat assumenda repellat.',
#   '1936-02-26',
#   1647,
#   '2022-02-17 22:15:41.550072',
#   '2022-02-17 22:15:41.550074',
#   '76.209.178.141'),
#  (674,
#   'Michael Williamson',
#   'kimberlymills@hotmail.com',
#   '844 Mcmillan Forge',
#   'Lake Bethmouth',
#   'Nova Scotia',
#   'Cameroon',
#   '(552) 690-7984',
#   'Dolores occaecati nobis tempore eveniet quis tempora eaque.',
#   '1908-03-31',
#   2256,
#   '2022-02-17 22:15:41.550980',
#   '2022-02-17 22:15:41.550982',
#   '11.95.34.72'),
#  (675,
#   'Daniel Knapp',
#   'gouldhannah@hotmail.com',
#   '9578 Jeff Garden Apt. 049',
#   'Lake Lindsayborough',
#   'Ontario',
#   'Azerbaijan',
#   '1-478-958-4058',
#   'Dignissimos quos enim pariatur perferendis in.',
#   '1922-04-13',
#   2485,
#   '2022-02-17 22:15:41.552001',
#   '2022-02-17 22:15:41.552003',
#   '214.58.189.242'),
#  (676,
#   'Terry Lindsey',
#   'xwatson@yahoo.com',
#   '7275 Marshall Square Suite 262',
#   'Deanborough',
#   'New Brunswick',
#   'Belgium',
#   '(923) 851-8489',
#   'Sapiente deserunt beatae tenetur voluptas alias eveniet earum quibusdam '
#   'exercitationem.',
#   '1965-06-18',
#   1819,
#   '2022-02-17 22:15:41.553226',
#   '2022-02-17 22:15:41.553228',
#   '99.126.242.42'),
#  (677,
#   'Robert Herrera',
#   'cynthia22@yahoo.com',
#   '157 Daniel Estate',
#   'Morrisborough',
#   'Nunavut',
#   'Sierra Leone',
#   '1 (995) 603-5559',
#   'Eius nesciunt eius nemo nesciunt voluptates.',
#   '2008-12-23',
#   2392,
#   '2022-02-17 22:15:41.554493',
#   '2022-02-17 22:15:41.554496',
#   '198.229.83.56'),
#  (678,
#   'Thomas Cameron',
#   'zlynch@yahoo.com',
#   '0087 Robert Landing Suite 649',
#   'Taraborough',
#   'British Columbia',
#   'French Guiana',
#   '1 (631) 313-8405',
#   'Sequi id nam enim magni recusandae.',
#   '2012-05-08',
#   1270,
#   '2022-02-17 22:15:41.555824',
#   '2022-02-17 22:15:41.555826',
#   '196.27.132.158'),
#  (679,
#   'Alyssa Thomas',
#   'julie97@yahoo.com',
#   '741 Gary Pines',
#   'Austinhaven',
#   'Nunavut',
#   'Liechtenstein',
#   '(974) 176-4785',
#   'Ullam facere accusamus veritatis quam occaecati minima libero culpa maxime.',
#   '1973-01-01',
#   1835,
#   '2022-02-17 22:15:41.557029',
#   '2022-02-17 22:15:41.557031',
#   '56.133.252.93'),
#  (680,
#   'Jaime Potter',
#   'catherinemcdaniel@gmail.com',
#   '42147 Tyler Drives Apt. 227',
#   'Alexisport',
#   'Newfoundland and Labrador',
#   'Comoros',
#   '715 421 1276',
#   'Excepturi numquam harum doloribus voluptatum iure temporibus commodi '
#   'aspernatur.',
#   '1973-11-26',
#   1929,
#   '2022-02-17 22:15:41.558305',
#   '2022-02-17 22:15:41.558308',
#   '205.194.213.44'),
#  (681,
#   'Mark King',
#   'bruce26@curtis-wilkerson.biz',
#   '7736 Nicole Underpass',
#   'Patriciaport',
#   'British Columbia',
#   'Central African Republic',
#   '(729) 103-8427 x698',
#   'Illo debitis maxime excepturi dolor sed distinctio dolor ducimus vel.',
#   '1926-07-18',
#   1848,
#   '2022-02-17 22:15:41.559218',
#   '2022-02-17 22:15:41.559220',
#   '119.189.55.9'),
#  (682,
#   'Teresa Lawrence',
#   'salasmariah@hotmail.com',
#   '32764 Debbie Throughway Suite 010',
#   'South Anthony',
#   'British Columbia',
#   'Mongolia',
#   '504.675.4450',
#   'Consectetur occaecati at dignissimos quasi.',
#   '1919-08-04',
#   2418,
#   '2022-02-17 22:15:41.560011',
#   '2022-02-17 22:15:41.560012',
#   '116.246.81.69'),
#  (683,
#   'Michael Woods',
#   'ashaw@larsen-hansen.org',
#   '749 Jennifer Meadow Suite 815',
#   'Clintonmouth',
#   'Newfoundland and Labrador',
#   'Puerto Rico',
#   '684 103 3340',
#   'Iusto magnam doloremque expedita deleniti.',
#   '1975-11-21',
#   1304,
#   '2022-02-17 22:15:41.560947',
#   '2022-02-17 22:15:41.560948',
#   '130.142.94.196'),
#  (684,
#   'Austin Davis',
#   'lmason@gmail.com',
#   '447 Connie Branch',
#   'East Anne',
#   'Northwest Territories',
#   'Nauru',
#   '279 588 3702',
#   'Repudiandae ab aspernatur nihil id eius.',
#   '1932-04-02',
#   1728,
#   '2022-02-17 22:15:41.561651',
#   '2022-02-17 22:15:41.561652',
#   '195.50.171.196'),
#  (685,
#   'Megan James',
#   'lisa19@gmail.com',
#   '174 Emma Causeway',
#   'Lake Michaelhaven',
#   'Yukon Territory',
#   'Singapore',
#   '606-542-1751 x962',
#   'Quasi in libero dolor corporis.',
#   '1920-02-01',
#   1235,
#   '2022-02-17 22:15:41.562335',
#   '2022-02-17 22:15:41.562337',
#   '65.147.170.35'),
#  (686,
#   'Anthony Lewis',
#   'gallagherrobert@yahoo.com',
#   '104 Cesar Inlet Suite 651',
#   'Foxstad',
#   'New Brunswick',
#   'Jamaica',
#   '1-822-169-3363',
#   'Voluptatibus repellat nisi eos aspernatur quasi et eius aperiam.',
#   '1970-09-12',
#   1969,
#   '2022-02-17 22:15:41.563111',
#   '2022-02-17 22:15:41.563113',
#   '80.39.49.155'),
#  (687,
#   'Terri Flores',
#   'ericking@phillips-kelly.biz',
#   '369 Francis Squares',
#   'Port Monicabury',
#   'Quebec',
#   'Guernsey',
#   '869-447-6637 x240',
#   'Debitis culpa illum ex odio consequuntur exercitationem.',
#   '1992-01-03',
#   1103,
#   '2022-02-17 22:15:41.564104',
#   '2022-02-17 22:15:41.564105',
#   '101.79.29.117'),
#  (688,
#   'Erik Jones',
#   'wphillips@harris-robinson.net',
#   '763 Jacob Route Apt. 376',
#   'Dyerton',
#   'Newfoundland and Labrador',
#   'Angola',
#   '1-428-059-6015',
#   'Corrupti deserunt nihil aut mollitia cupiditate accusamus necessitatibus '
#   'commodi occaecati.',
#   '1988-04-09',
#   1317,
#   '2022-02-17 22:15:41.565017',
#   '2022-02-17 22:15:41.565018',
#   '135.19.113.162'),
#  (689,
#   'Debbie Brewer',
#   'qmurray@yahoo.com',
#   '2222 Troy Station Apt. 147',
#   'Lake Jaclyntown',
#   'New Brunswick',
#   'Mayotte',
#   '1-301-277-6229',
#   'Ea soluta voluptatum quidem libero perferendis voluptas aut minus.',
#   '1954-08-05',
#   1206,
#   '2022-02-17 22:15:41.565733',
#   '2022-02-17 22:15:41.565734',
#   '110.241.140.185'),
#  (690,
#   'Katherine Greene',
#   'cmorton@hotmail.com',
#   '9763 Barbara Mews Apt. 854',
#   'Kyleside',
#   'Prince Edward Island',
#   'Tunisia',
#   '600-850-2936 x364',
#   'Deserunt nostrum nisi nobis voluptatibus a neque.',
#   '1936-06-25',
#   1274,
#   '2022-02-17 22:15:41.566447',
#   '2022-02-17 22:15:41.566449',
#   '61.146.138.177'),
#  (691,
#   'Laura Hicks',
#   'jennifer21@gmail.com',
#   '749 Caitlin Course Apt. 908',
#   'Tinaberg',
#   'British Columbia',
#   'Saint Pierre and Miquelon',
#   '(794) 342-5415',
#   'Ex commodi velit blanditiis error voluptatum alias commodi iusto nesciunt.',
#   '1935-11-19',
#   2253,
#   '2022-02-17 22:15:41.567114',
#   '2022-02-17 22:15:41.567116',
#   '83.233.244.81'),
#  (692,
#   'Dr. Sara Moore',
#   'hramirez@hotmail.com',
#   '7086 Smith Ferry Suite 202',
#   'Lake Jasonview',
#   'Ontario',
#   'Mongolia',
#   '257-628-6073',
#   'Illo dolorem dolores modi ab hic veritatis repudiandae rem.',
#   '1981-07-15',
#   1143,
#   '2022-02-17 22:15:41.567868',
#   '2022-02-17 22:15:41.567869',
#   '12.4.86.101'),
#  (693,
#   'Lori Patton',
#   'sgray@arellano.org',
#   '797 Good Gateway Suite 251',
#   'New Jeremy',
#   'Manitoba',
#   'Holy See (Vatican City State)',
#   '(165) 250-3926',
#   'Facere corporis alias iste explicabo natus sunt aperiam.',
#   '1934-05-23',
#   2359,
#   '2022-02-17 22:15:41.568842',
#   '2022-02-17 22:15:41.568843',
#   '64.81.142.206'),
#  (694,
#   'Bryan Richards',
#   'garnerjulie@yahoo.com',
#   '969 Price Hills Suite 678',
#   'New Autumnport',
#   'Saskatchewan',
#   'Svalbard & Jan Mayen Islands',
#   '(894) 627-5068 x627',
#   'Officia deleniti ipsum optio blanditiis explicabo culpa.',
#   '1927-05-03',
#   1818,
#   '2022-02-17 22:15:41.569639',
#   '2022-02-17 22:15:41.569641',
#   '155.239.81.21'),
#  (695,
#   'Dylan Thompson',
#   'keith03@gonzalez.com',
#   '740 Laurie Groves',
#   'New Donnaville',
#   'British Columbia',
#   'New Caledonia',
#   '(185) 425-8346',
#   'Esse ut explicabo impedit soluta voluptas saepe itaque.',
#   '1915-03-17',
#   2068,
#   '2022-02-17 22:15:41.570569',
#   '2022-02-17 22:15:41.570570',
#   '105.171.218.74'),
#  (696,
#   'Edward Lewis',
#   'laura31@hayes-smith.com',
#   '8544 Mark Ville',
#   'Marshallview',
#   'Nunavut',
#   'Palestinian Territory',
#   '(176) 386-0378 x340',
#   'Culpa doloremque optio illum tempore incidunt facere quia ab.',
#   '1955-12-20',
#   2185,
#   '2022-02-17 22:15:41.571448',
#   '2022-02-17 22:15:41.571449',
#   '221.4.147.170'),
#  (697,
#   'Sophia Medina',
#   'chadbray@burgess-barton.net',
#   '1333 Mendoza Island Suite 318',
#   'South Joshuafort',
#   'Nunavut',
#   'Qatar',
#   '852.577.5374',
#   'Laborum maxime odio occaecati quod.',
#   '1909-10-09',
#   1712,
#   '2022-02-17 22:15:41.572410',
#   '2022-02-17 22:15:41.572412',
#   '99.191.54.112'),
#  (698,
#   'Walter Johnson',
#   'poconnor@arellano.com',
#   '746 Carter Parkways Suite 974',
#   'Vasquezside',
#   'Yukon Territory',
#   'Monaco',
#   '+1 (715) 930-0071',
#   'Corporis ducimus pariatur ipsa atque alias velit.',
#   '2009-06-07',
#   1056,
#   '2022-02-17 22:15:41.573421',
#   '2022-02-17 22:15:41.573422',
#   '148.170.127.106'),
#  (699,
#   'Christopher Michael',
#   'wayne62@hotmail.com',
#   '68229 Cruz Crossroad Apt. 420',
#   'West Terrifurt',
#   'Northwest Territories',
#   'Djibouti',
#   '952 778 2668',
#   'Ab ea accusantium nisi veritatis esse quod.',
#   '1965-03-08',
#   2368,
#   '2022-02-17 22:15:41.574157',
#   '2022-02-17 22:15:41.574159',
#   '23.32.109.197'),
#  (700,
#   'Deborah Miller',
#   'walkermark@gmail.com',
#   '88094 Watts Oval',
#   'New Tonya',
#   'Yukon Territory',
#   'Saudi Arabia',
#   '+1 (758) 690-0019',
#   'Cum debitis asperiores voluptatibus saepe porro.',
#   '1919-10-14',
#   1481,
#   '2022-02-17 22:15:41.574923',
#   '2022-02-17 22:15:41.574925',
#   '50.77.24.39'),
#  (701,
#   'Tonya Wagner',
#   'sparsons@gmail.com',
#   '680 Cooke Lights',
#   'Lake Amanda',
#   'Alberta',
#   'Ecuador',
#   '1 (369) 082-2030',
#   'Eum tenetur laboriosam repudiandae doloribus reiciendis debitis.',
#   '1982-08-20',
#   1179,
#   '2022-02-17 22:15:41.575637',
#   '2022-02-17 22:15:41.575639',
#   '2.238.123.84'),
#  (702,
#   'Denise Beck',
#   'pricehenry@gmail.com',
#   '9435 Peterson Turnpike Suite 832',
#   'Marquezland',
#   'Ontario',
#   'Comoros',
#   '+1 (642) 314-2478',
#   'Asperiores magni deserunt fuga cupiditate corporis autem ab.',
#   '1973-02-07',
#   1053,
#   '2022-02-17 22:15:41.576444',
#   '2022-02-17 22:15:41.576445',
#   '196.206.26.235'),
#  (703,
#   'Jeremy Brandt',
#   'hhebert@taylor-daniel.info',
#   '896 Bennett Street',
#   'North Lisa',
#   'Northwest Territories',
#   'Sri Lanka',
#   '(482) 973-2768 x122',
#   'Pariatur molestias architecto sequi voluptatem reprehenderit suscipit '
#   'dignissimos aperiam.',
#   '1969-05-25',
#   1031,
#   '2022-02-17 22:15:41.577329',
#   '2022-02-17 22:15:41.577332',
#   '112.51.106.15'),
#  (704,
#   'Debbie White',
#   'lunajanice@yahoo.com',
#   '39819 Christopher Valley',
#   'Annaberg',
#   'British Columbia',
#   'Syrian Arab Republic',
#   '(161) 838-8708',
#   'Dolore rerum iusto cupiditate natus unde repellat eos placeat.',
#   '1957-09-15',
#   1123,
#   '2022-02-17 22:15:41.578071',
#   '2022-02-17 22:15:41.578072',
#   '196.233.55.237'),
#  (705,
#   'Dawn Hubbard',
#   'eparker@hotmail.com',
#   '025 Osborne Spur',
#   'Port Stephanie',
#   'Quebec',
#   'Mayotte',
#   '1 (965) 822-3335',
#   'Officiis accusantium vero non tempore aliquid.',
#   '1918-09-03',
#   1577,
#   '2022-02-17 22:15:41.578785',
#   '2022-02-17 22:15:41.578786',
#   '222.232.248.130'),
#  (706,
#   'Susan Coleman DVM',
#   'jose34@gmail.com',
#   '181 Brown Summit',
#   'Lyonston',
#   'British Columbia',
#   'Martinique',
#   '844-369-1855 x269',
#   'Perspiciatis possimus unde placeat culpa magni ducimus dolor ipsum nam.',
#   '2019-10-16',
#   1347,
#   '2022-02-17 22:15:41.579527',
#   '2022-02-17 22:15:41.579528',
#   '147.160.197.7'),
#  (707,
#   'Greg Wallace',
#   'briantaylor@jackson.info',
#   '55977 Wang Stream',
#   'Robertmouth',
#   'Nunavut',
#   'Saint Kitts and Nevis',
#   '(143) 194-3164 x880',
#   'Praesentium error culpa modi voluptas quisquam molestiae soluta.',
#   '1918-09-02',
#   2176,
#   '2022-02-17 22:15:41.580729',
#   '2022-02-17 22:15:41.580731',
#   '10.178.24.16'),
#  (708,
#   'Betty Potts',
#   'andersonbenjamin@gmail.com',
#   '697 Duncan Highway',
#   'Valerieville',
#   'Ontario',
#   'Palau',
#   '+1 (947) 014-8659',
#   'Laborum vero at quisquam similique magni quod corrupti quas fugit.',
#   '1926-06-14',
#   1898,
#   '2022-02-17 22:15:41.581686',
#   '2022-02-17 22:15:41.581687',
#   '196.197.103.80'),
#  (709,
#   'Jeremiah Warren',
#   'laurieadams@hotmail.com',
#   '242 Fischer Locks Apt. 458',
#   'East Annemouth',
#   'Northwest Territories',
#   'Cuba',
#   '114 061 5792',
#   'Quam beatae reiciendis blanditiis aliquam vero dolores.',
#   '2019-05-20',
#   1398,
#   '2022-02-17 22:15:41.582546',
#   '2022-02-17 22:15:41.582547',
#   '40.126.34.172'),
#  (710,
#   'Daniel Gonzalez',
#   'justin66@crane.com',
#   '215 Tina Key',
#   'Juliemouth',
#   'Ontario',
#   'Reunion',
#   '(495) 956-0307 x122',
#   'Praesentium in odio atque maxime enim doloremque velit at.',
#   '2003-11-29',
#   1442,
#   '2022-02-17 22:15:41.583527',
#   '2022-02-17 22:15:41.583528',
#   '192.28.24.111'),
#  (711,
#   'Victoria Morrison',
#   'karalopez@hotmail.com',
#   '8929 Mark Court Apt. 681',
#   'Nicholashaven',
#   'Ontario',
#   'Sri Lanka',
#   '536 543 5138',
#   'Earum dicta consequuntur laboriosam perferendis ab.',
#   '1957-03-23',
#   1304,
#   '2022-02-17 22:15:41.584301',
#   '2022-02-17 22:15:41.584302',
#   '122.18.69.242'),
#  (712,
#   'Oscar Tucker',
#   'hrichardson@johnson.com',
#   '87992 Shaw Haven Suite 250',
#   'Bellmouth',
#   'Nova Scotia',
#   'Congo',
#   '+1 (539) 796-7503',
#   'Animi facere perspiciatis ut vero esse quasi error.',
#   '1987-03-29',
#   2337,
#   '2022-02-17 22:15:41.585427',
#   '2022-02-17 22:15:41.585429',
#   '38.89.104.66'),
#  (713,
#   'Tanya Wilson',
#   'laurabenson@torres.com',
#   '296 Cain Avenue',
#   'Mataside',
#   'Prince Edward Island',
#   'Mayotte',
#   '714-095-6958 x630',
#   'Nostrum architecto quisquam saepe voluptatum ut maiores perferendis '
#   'commodi.',
#   '1940-06-26',
#   2383,
#   '2022-02-17 22:15:41.586346',
#   '2022-02-17 22:15:41.586348',
#   '83.56.25.4'),
#  (714,
#   'Michael Hill',
#   'taylorjerry@valencia.org',
#   '60216 Brian Circles',
#   'Port Christy',
#   'Ontario',
#   'Dominican Republic',
#   '(346) 533-3474',
#   'Quam hic odit officia repudiandae rem quos dolores quasi mollitia eaque.',
#   '1991-04-12',
#   2084,
#   '2022-02-17 22:15:41.587366',
#   '2022-02-17 22:15:41.587367',
#   '8.140.158.118'),
#  (715,
#   'John Yoder',
#   'bwood@hotmail.com',
#   '97331 Baker Inlet Suite 244',
#   'East Darrell',
#   'British Columbia',
#   'South Georgia and the South Sandwich Islands',
#   '1-949-106-4010',
#   'Tempore molestiae eaque unde soluta aspernatur quis animi.',
#   '1946-12-17',
#   2192,
#   '2022-02-17 22:15:41.588088',
#   '2022-02-17 22:15:41.588090',
#   '155.37.232.126'),
#  (716,
#   'Gail Soto',
#   'richard36@hotmail.com',
#   '15234 Smith Haven',
#   'Seanfurt',
#   'Yukon Territory',
#   'Fiji',
#   '(657) 401-7829 x113',
#   'Culpa consectetur inventore itaque incidunt.',
#   '1954-03-24',
#   2389,
#   '2022-02-17 22:15:41.588842',
#   '2022-02-17 22:15:41.588844',
#   '112.205.162.160'),
#  (717,
#   'Robert Carpenter MD',
#   'pauljohnson@tate.net',
#   '6824 Robinson Expressway Apt. 919',
#   'New Lisamouth',
#   'Nunavut',
#   'Russian Federation',
#   '246-598-8172 x480',
#   'Maiores ipsa ipsum iusto culpa assumenda explicabo reprehenderit voluptatem '
#   'quam labore.',
#   '1969-01-28',
#   1771,
#   '2022-02-17 22:15:41.589785',
#   '2022-02-17 22:15:41.589787',
#   '164.212.173.231'),
#  (718,
#   'Jonathan Clark',
#   'staceycrawford@hotmail.com',
#   '0735 Thomas Groves',
#   'Contrerasbury',
#   'British Columbia',
#   'Turkey',
#   '(749) 434-3101 x748',
#   'Molestias repudiandae ullam ad voluptatem cupiditate repellendus.',
#   '2006-03-12',
#   1235,
#   '2022-02-17 22:15:41.590590',
#   '2022-02-17 22:15:41.590591',
#   '21.230.149.148'),
#  (719,
#   'Stephanie Ramirez',
#   'jesse96@gmail.com',
#   '28345 Andrew Camp',
#   'Xaviermouth',
#   'Ontario',
#   'Niger',
#   '696-483-0606 x330',
#   'Laborum magnam iure in voluptates ullam tempore consequatur.',
#   '1912-11-20',
#   2163,
#   '2022-02-17 22:15:41.591258',
#   '2022-02-17 22:15:41.591260',
#   '171.130.34.175'),
#  (720,
#   'Nancy Dawson',
#   'james89@hanson.com',
#   '712 Tracy Vista',
#   'Lake Deborah',
#   'Newfoundland and Labrador',
#   'South Africa',
#   '+1 (467) 337-1273',
#   'Nesciunt accusantium expedita ea numquam.',
#   '1915-06-10',
#   2134,
#   '2022-02-17 22:15:41.592183',
#   '2022-02-17 22:15:41.592185',
#   '106.41.250.241'),
#  (721,
#   'Kevin Pitts',
#   'hunter08@yahoo.com',
#   '5061 Mariah Junctions',
#   'New Jacobchester',
#   'Quebec',
#   'United States Minor Outlying Islands',
#   '263.945.3916',
#   'Suscipit eligendi pariatur doloremque omnis.',
#   '1954-04-01',
#   1855,
#   '2022-02-17 22:15:41.592867',
#   '2022-02-17 22:15:41.592868',
#   '47.2.142.155'),
#  (722,
#   'Jennifer Martin',
#   'christopherdalton@rodriguez.com',
#   '841 Jessica Extensions Apt. 319',
#   'Markville',
#   'Prince Edward Island',
#   'Benin',
#   '882.713.3659',
#   'Quod excepturi impedit ipsam reiciendis provident distinctio maxime '
#   'consequatur.',
#   '1977-05-23',
#   1886,
#   '2022-02-17 22:15:41.593920',
#   '2022-02-17 22:15:41.593922',
#   '185.219.249.209'),
#  (723,
#   'Brandon Patterson',
#   'harrismartin@reyes-robles.com',
#   '498 Watson Parkways',
#   'Lake Samanthabury',
#   'Saskatchewan',
#   'Saint Vincent and the Grenadines',
#   '+1 (512) 231-7732',
#   'Porro officia minus rerum sunt.',
#   '2016-01-08',
#   2035,
#   '2022-02-17 22:15:41.594917',
#   '2022-02-17 22:15:41.594918',
#   '80.18.112.84'),
#  (724,
#   'Tara Miller',
#   'ethanfarmer@yahoo.com',
#   '92275 Timothy Mill',
#   'Ashleyland',
#   'Ontario',
#   'Turkey',
#   '779.144.3600',
#   'In nisi ullam provident quam.',
#   '1918-08-28',
#   2059,
#   '2022-02-17 22:15:41.595706',
#   '2022-02-17 22:15:41.595708',
#   '179.200.175.88'),
#  (725,
#   'Vanessa Robinson',
#   'danielle68@henderson-smith.com',
#   '828 Weeks Freeway',
#   'Smithhaven',
#   'Yukon Territory',
#   'Benin',
#   '(897) 280-8040',
#   'Nesciunt sapiente explicabo animi tempore.',
#   '1932-10-25',
#   2192,
#   '2022-02-17 22:15:41.596610',
#   '2022-02-17 22:15:41.596611',
#   '149.72.165.45'),
#  (726,
#   'Anthony Harrison',
#   'sabrina36@hotmail.com',
#   '02865 Frederick Lock',
#   'East Michaelstad',
#   'British Columbia',
#   'Syrian Arab Republic',
#   '(640) 103-0776',
#   'Labore ipsa rem numquam eum praesentium tempore officia.',
#   '1981-01-29',
#   1268,
#   '2022-02-17 22:15:41.597281',
#   '2022-02-17 22:15:41.597282',
#   '134.58.252.77'),
#  (727,
#   'Seth Davis',
#   'tdunn@hotmail.com',
#   '5999 Jones Knolls',
#   'Hoganborough',
#   'Saskatchewan',
#   'Samoa',
#   '474.923.5673',
#   'Qui praesentium vitae totam enim.',
#   '1986-08-09',
#   1058,
#   '2022-02-17 22:15:41.598013',
#   '2022-02-17 22:15:41.598015',
#   '223.88.140.250'),
#  (728,
#   'Samantha Hughes',
#   'zmunoz@hotmail.com',
#   '45759 Amanda Harbors Apt. 265',
#   'Andreafurt',
#   'Nunavut',
#   'Botswana',
#   '1 (817) 993-0953',
#   'Dignissimos quos fugiat eveniet omnis quidem aut deleniti veniam.',
#   '1948-08-24',
#   1142,
#   '2022-02-17 22:15:41.598729',
#   '2022-02-17 22:15:41.598731',
#   '42.49.178.217'),
#  (729,
#   'Daniel Campbell',
#   'andrew69@campbell.net',
#   '468 Gina Extensions Apt. 317',
#   'Martinezfort',
#   'Nova Scotia',
#   'Uruguay',
#   '(375) 941-3426',
#   'Maiores explicabo corporis voluptas nulla vitae.',
#   '2006-07-03',
#   1658,
#   '2022-02-17 22:15:41.599541',
#   '2022-02-17 22:15:41.599543',
#   '6.228.51.19'),
#  (730,
#   'Robert Garza',
#   'scott97@hotmail.com',
#   '0608 Morrow Light',
#   'West Emily',
#   'Quebec',
#   'Greenland',
#   '1-477-462-6153',
#   'Quae accusamus modi harum dolorem magni odio.',
#   '1918-10-02',
#   1609,
#   '2022-02-17 22:15:41.600216',
#   '2022-02-17 22:15:41.600218',
#   '130.169.215.170'),
#  (731,
#   'Alex Meyer Jr.',
#   'lrichardson@yahoo.com',
#   '51724 Jonathan Coves',
#   'Jacquelineview',
#   'Prince Edward Island',
#   'South Africa',
#   '922 034 9331',
#   'Modi sint accusamus accusamus alias sint asperiores.',
#   '1923-09-07',
#   1924,
#   '2022-02-17 22:15:41.600918',
#   '2022-02-17 22:15:41.600920',
#   '205.202.166.165'),
#  (732,
#   'Antonio Lane',
#   'kylemitchell@hotmail.com',
#   '8032 Barnes Flat',
#   'Moorefort',
#   'British Columbia',
#   'Switzerland',
#   '1 (211) 377-5600',
#   'Dolores iusto minus ipsam maiores cum.',
#   '1935-05-26',
#   1984,
#   '2022-02-17 22:15:41.601713',
#   '2022-02-17 22:15:41.601714',
#   '134.32.248.150'),
#  (733,
#   'Bradley Mason',
#   'ruizbarry@yahoo.com',
#   '91603 Curtis Creek Apt. 543',
#   'Port Michealmouth',
#   'Quebec',
#   'Brunei Darussalam',
#   '491 398 0520',
#   'Alias error maiores nulla temporibus nulla minus magnam et illo.',
#   '1920-09-26',
#   1496,
#   '2022-02-17 22:15:41.602492',
#   '2022-02-17 22:15:41.602493',
#   '30.239.241.167'),
#  (734,
#   'Crystal Lopez',
#   'oliviastevens@smith.org',
#   '9747 Casey Trail',
#   'Timothyhaven',
#   'Ontario',
#   'Congo',
#   '408-345-7456 x254',
#   'Ab doloremque et tempore nulla.',
#   '1993-10-15',
#   2281,
#   '2022-02-17 22:15:41.603373',
#   '2022-02-17 22:15:41.603375',
#   '60.245.85.5'),
#  (735,
#   'Courtney Montgomery',
#   'kara76@yahoo.com',
#   '695 Jessica Mission',
#   'Johnton',
#   'Nunavut',
#   'Suriname',
#   '+1 (703) 456-6032',
#   'Aut placeat adipisci impedit voluptas iure optio.',
#   '1930-05-22',
#   1492,
#   '2022-02-17 22:15:41.604035',
#   '2022-02-17 22:15:41.604036',
#   '105.175.4.160'),
#  (736,
#   'Natasha Byrd',
#   'kristin31@ross.net',
#   '026 Alexander Curve Apt. 808',
#   'Joshuafort',
#   'Nunavut',
#   'French Polynesia',
#   '339 123 1177',
#   'Culpa labore dicta modi maxime autem dicta voluptate commodi.',
#   '1913-02-26',
#   1788,
#   '2022-02-17 22:15:41.604859',
#   '2022-02-17 22:15:41.604861',
#   '41.249.122.52'),
#  (737,
#   'James Perez',
#   'jordanmonica@yu.com',
#   '5884 Kayla Mission',
#   'Jenkinsmouth',
#   'British Columbia',
#   'San Marino',
#   '+1 (639) 884-4669',
#   'A tempore sapiente quos labore voluptatem repellendus ducimus cum.',
#   '1916-04-09',
#   1629,
#   '2022-02-17 22:15:41.605883',
#   '2022-02-17 22:15:41.605884',
#   '138.182.172.235'),
#  (738,
#   'Jodi Walker',
#   'rlyons@yahoo.com',
#   '0705 Michelle Junctions Suite 688',
#   'Lake Robert',
#   'British Columbia',
#   'Tonga',
#   '(226) 158-6449',
#   'Maiores consequatur officia sed laboriosam temporibus molestias odio.',
#   '2011-09-12',
#   1771,
#   '2022-02-17 22:15:41.606613',
#   '2022-02-17 22:15:41.606614',
#   '21.218.197.228'),
#  (739,
#   'Lindsay Mcdaniel',
#   'annayoung@weiss-white.com',
#   '049 Michele Orchard Apt. 494',
#   'Lake Valeriefurt',
#   'Prince Edward Island',
#   'Benin',
#   '1 (770) 118-0301',
#   'Tempora laborum voluptatem maiores corporis officia corporis natus dicta '
#   'dolor.',
#   '1969-01-14',
#   2355,
#   '2022-02-17 22:15:41.607564',
#   '2022-02-17 22:15:41.607566',
#   '12.82.13.0'),
#  (740,
#   'Laura Pitts',
#   'klong@yahoo.com',
#   '030 Patty Alley Apt. 973',
#   'Sampsonstad',
#   'Yukon Territory',
#   'Moldova',
#   '849 967 0768',
#   'Quas dolorem nihil occaecati eum sequi.',
#   '1930-11-26',
#   2130,
#   '2022-02-17 22:15:41.608284',
#   '2022-02-17 22:15:41.608285',
#   '39.30.52.79'),
#  (741,
#   'Hannah Cole',
#   'nicole56@yahoo.com',
#   '92903 Ramirez Forges',
#   'Conleyhaven',
#   'Northwest Territories',
#   'Bahamas',
#   '(236) 449-1863 x664',
#   'Earum explicabo exercitationem et quos.',
#   '1995-06-07',
#   1876,
#   '2022-02-17 22:15:41.609010',
#   '2022-02-17 22:15:41.609012',
#   '102.177.42.93'),
#  (742,
#   'Karen Brown',
#   'uschmidt@bryant.com',
#   '716 Edwards Tunnel Apt. 847',
#   'Knightport',
#   'British Columbia',
#   'New Caledonia',
#   '(263) 907-9753',
#   'Soluta quae quam quasi laudantium.',
#   '2009-05-01',
#   2193,
#   '2022-02-17 22:15:41.610022',
#   '2022-02-17 22:15:41.610024',
#   '29.151.134.40'),
#  (743,
#   'Adam Riggs',
#   'sherylwhite@yahoo.com',
#   '55165 Bell Crest Apt. 195',
#   'New Leah',
#   'Ontario',
#   'Rwanda',
#   '1 (658) 168-5927',
#   'A architecto a quas accusantium aliquid a.',
#   '1984-04-25',
#   1870,
#   '2022-02-17 22:15:41.610824',
#   '2022-02-17 22:15:41.610826',
#   '82.42.251.50'),
#  (744,
#   'Lauren Barrett',
#   'salazarscott@williams.net',
#   '441 Coleman Inlet',
#   'West Lisa',
#   'Nova Scotia',
#   'Holy See (Vatican City State)',
#   '1-969-135-9456',
#   'Commodi dignissimos iusto vel nisi temporibus hic.',
#   '1960-05-07',
#   1018,
#   '2022-02-17 22:15:41.611707',
#   '2022-02-17 22:15:41.611708',
#   '151.92.211.110'),
#  (745,
#   'Stephanie Walsh',
#   'emontoya@yahoo.com',
#   '27539 Brady Flat Apt. 100',
#   'Jeffreyport',
#   'Nova Scotia',
#   'South Georgia and the South Sandwich Islands',
#   '542-118-4911 x548',
#   'Eligendi natus accusamus aperiam perspiciatis eius accusamus.',
#   '1987-06-09',
#   1595,
#   '2022-02-17 22:15:41.612464',
#   '2022-02-17 22:15:41.612465',
#   '16.175.199.119'),
#  (746,
#   'Eric Ingram',
#   'bradsmith@mcintyre.com',
#   '904 Harrington Mountain Suite 255',
#   'Rebeccaville',
#   'Quebec',
#   'Malta',
#   '(388) 327-9266',
#   'Reiciendis cumque cupiditate quos temporibus delectus suscipit perferendis.',
#   '1953-03-10',
#   1872,
#   '2022-02-17 22:15:41.613352',
#   '2022-02-17 22:15:41.613354',
#   '141.31.230.105'),
#  (747,
#   'Carol Williams',
#   'zpope@jennings.com',
#   '91987 Stephanie Camp',
#   'North Lisa',
#   'Yukon Territory',
#   'Vanuatu',
#   '(682) 105-0792 x060',
#   'Aliquam voluptatum ducimus voluptates voluptatum quam.',
#   '1999-12-18',
#   1879,
#   '2022-02-17 22:15:41.614355',
#   '2022-02-17 22:15:41.614358',
#   '56.161.60.157'),
#  (748,
#   'Victor Kim',
#   'obradley@gmail.com',
#   '541 Renee Fort',
#   'South Leah',
#   'Nova Scotia',
#   'France',
#   '(891) 016-8516',
#   'Vitae dolore iure earum placeat eligendi debitis praesentium.',
#   '1956-08-12',
#   1465,
#   '2022-02-17 22:15:41.615095',
#   '2022-02-17 22:15:41.615097',
#   '137.34.161.4'),
#  (749,
#   'Andrea Hayes',
#   'stacyrhodes@hotmail.com',
#   '307 Miranda Ports',
#   'Matthewland',
#   'Prince Edward Island',
#   'Saint Kitts and Nevis',
#   '402-486-7865',
#   'Asperiores iste vel sapiente consequuntur velit dolore assumenda qui.',
#   '1975-05-26',
#   1115,
#   '2022-02-17 22:15:41.615870',
#   '2022-02-17 22:15:41.615872',
#   '165.114.228.220'),
#  (750,
#   'Jasmine Lewis',
#   'longtroy@hernandez.org',
#   '286 Mark Field',
#   'Kaylabury',
#   'Manitoba',
#   'Northern Mariana Islands',
#   '450.936.6486',
#   'Possimus occaecati rem iure reiciendis animi.',
#   '1944-11-05',
#   1638,
#   '2022-02-17 22:15:41.616735',
#   '2022-02-17 22:15:41.616736',
#   '138.245.186.227'),
#  (751,
#   'Daniel Meyer',
#   'gsmith@long.com',
#   '524 Lindsey Prairie Suite 852',
#   'West Deniseland',
#   'Quebec',
#   'Nicaragua',
#   '514 977 5354',
#   'Deleniti reprehenderit laudantium aspernatur sapiente odio exercitationem.',
#   '2018-07-05',
#   1057,
#   '2022-02-17 22:15:41.617602',
#   '2022-02-17 22:15:41.617603',
#   '74.94.122.220'),
#  (752,
#   'Marilyn Mcintyre',
#   'crystalwarner@carter.com',
#   '343 Mills Field',
#   'Suarezmouth',
#   'Newfoundland and Labrador',
#   'Iceland',
#   '(943) 087-1056',
#   'Ratione dicta animi iure corrupti beatae magnam inventore sint.',
#   '1932-02-22',
#   1967,
#   '2022-02-17 22:15:41.618653',
#   '2022-02-17 22:15:41.618655',
#   '139.85.143.15'),
#  (753,
#   'Jessica Evans',
#   'amypowell@lewis-mcdonald.org',
#   '672 Young Light',
#   'Joeltown',
#   'Northwest Territories',
#   'Malawi',
#   '322 181 1324',
#   'Perferendis eligendi eaque officia veniam quasi.',
#   '1991-11-13',
#   1105,
#   '2022-02-17 22:15:41.619593',
#   '2022-02-17 22:15:41.619595',
#   '113.18.244.138'),
#  (754,
#   'Noah Fowler',
#   'omiller@yahoo.com',
#   '5887 Dodson Junction Suite 772',
#   'Robinsonshire',
#   'Saskatchewan',
#   'Romania',
#   '217 678 3033',
#   'Debitis expedita praesentium velit soluta corrupti quaerat quibusdam '
#   'itaque.',
#   '1997-10-17',
#   1533,
#   '2022-02-17 22:15:41.620347',
#   '2022-02-17 22:15:41.620349',
#   '201.247.129.32'),
#  (755,
#   'Patricia Rodriguez',
#   'hernandezkristi@patterson.com',
#   '08777 Roberts Common Apt. 264',
#   'Joelport',
#   'Yukon Territory',
#   'Greenland',
#   '(463) 288-1800 x533',
#   'Corporis a reiciendis adipisci consectetur qui aut nulla.',
#   '1939-05-16',
#   2378,
#   '2022-02-17 22:15:41.621394',
#   '2022-02-17 22:15:41.621396',
#   '43.82.107.144'),
#  (756,
#   'Cheryl Wilson',
#   'oconnorjohn@gonzales-odom.com',
#   '13553 Horn Junctions',
#   'Port Trevorstad',
#   'Northwest Territories',
#   'Ireland',
#   '1-944-484-2503',
#   'Quas iusto necessitatibus numquam culpa voluptatibus magni harum dolorem.',
#   '1944-02-06',
#   1113,
#   '2022-02-17 22:15:41.622341',
#   '2022-02-17 22:15:41.622343',
#   '1.39.252.129'),
#  (757,
#   'James Mcdonald',
#   'trevinokristina@yahoo.com',
#   '396 Charles Gardens Apt. 654',
#   'Davidmouth',
#   'British Columbia',
#   'Turkmenistan',
#   '(195) 300-2690 x529',
#   'Cum veritatis sunt sit ducimus accusantium reiciendis nesciunt porro ipsam.',
#   '1938-07-27',
#   1289,
#   '2022-02-17 22:15:41.623101',
#   '2022-02-17 22:15:41.623103',
#   '108.250.249.231'),
#  (758,
#   'Desiree Mack',
#   'dwalker@gmail.com',
#   '16008 Jerome Tunnel',
#   'Matthewburgh',
#   'Prince Edward Island',
#   'Belize',
#   '+1 (229) 318-0551',
#   'Impedit accusamus sit itaque non excepturi aliquam animi perferendis.',
#   '1919-04-05',
#   1027,
#   '2022-02-17 22:15:41.623797',
#   '2022-02-17 22:15:41.623799',
#   '194.210.233.161'),
#  (759,
#   'Colleen Miller',
#   'elizabeth33@berger.com',
#   '8658 Wood Way',
#   'New Thomas',
#   'Nunavut',
#   'Benin',
#   '(895) 425-2919',
#   'Dolor sed magnam earum quae aperiam explicabo autem quibusdam recusandae.',
#   '1906-12-18',
#   1395,
#   '2022-02-17 22:15:41.624653',
#   '2022-02-17 22:15:41.624655',
#   '146.50.118.6'),
#  (760,
#   'Lori Allen',
#   'melissabrown@sanchez.com',
#   '43255 Kelsey Field',
#   'Ortizfurt',
#   'Yukon Territory',
#   'Bolivia',
#   '1-972-017-8427',
#   'Et nisi voluptas quisquam velit voluptatum perspiciatis.',
#   '1981-01-13',
#   1553,
#   '2022-02-17 22:15:41.625541',
#   '2022-02-17 22:15:41.625542',
#   '63.97.78.119'),
#  (761,
#   'Candace Lewis',
#   'ngrimes@strong.com',
#   '202 Meyers Lights',
#   'Lake Gregory',
#   'Manitoba',
#   'Faroe Islands',
#   '271 084 7273',
#   'Eum quibusdam tempora nam ipsam provident nam porro voluptatem enim.',
#   '2008-11-23',
#   1959,
#   '2022-02-17 22:15:41.626517',
#   '2022-02-17 22:15:41.626518',
#   '96.65.152.78'),
#  (762,
#   'Nicholas Barnes',
#   'frederickbrooks@gmail.com',
#   '9012 Woods Landing',
#   'Lake Alicia',
#   'Prince Edward Island',
#   'Uzbekistan',
#   '+1 (714) 393-5738',
#   'Esse cumque rem iusto rerum repellendus nulla quisquam exercitationem.',
#   '1914-05-05',
#   1755,
#   '2022-02-17 22:15:41.627298',
#   '2022-02-17 22:15:41.627300',
#   '196.210.222.67'),
#  (763,
#   'Aaron Cowan',
#   'maria44@malone.com',
#   '72004 Lauren Radial Apt. 420',
#   'Katherinebury',
#   'Northwest Territories',
#   'Armenia',
#   '1-728-249-0352',
#   'Dolor unde doloremque saepe eveniet aut voluptas.',
#   '1945-11-12',
#   1375,
#   '2022-02-17 22:15:41.628261',
#   '2022-02-17 22:15:41.628263',
#   '52.63.81.108'),
#  (764,
#   'Elizabeth Gomez',
#   'mharris@gmail.com',
#   '95352 Brown Common',
#   'Lake Whitneyburgh',
#   'Nunavut',
#   'Hong Kong',
#   '+1 (220) 569-5697',
#   'Omnis minima nobis similique est autem.',
#   '2013-07-20',
#   2400,
#   '2022-02-17 22:15:41.628986',
#   '2022-02-17 22:15:41.628987',
#   '217.166.58.76'),
#  (765,
#   'Rebecca Sims',
#   'qdurham@phillips.com',
#   '173 Cheryl Station',
#   'North Emily',
#   'Yukon Territory',
#   'Norway',
#   '618-093-6624',
#   'Atque eveniet quaerat autem distinctio rem odit illo.',
#   '2014-04-12',
#   1761,
#   '2022-02-17 22:15:41.629926',
#   '2022-02-17 22:15:41.629928',
#   '216.79.141.3'),
#  (766,
#   'Joshua Miller',
#   'christina20@davidson.com',
#   '549 Fields Manor Apt. 884',
#   'Smithtown',
#   'New Brunswick',
#   'Italy',
#   '(128) 203-6910',
#   'Quibusdam possimus sint hic ipsa dignissimos reiciendis.',
#   '1931-07-14',
#   1433,
#   '2022-02-17 22:15:41.630767',
#   '2022-02-17 22:15:41.630768',
#   '60.18.80.232'),
#  (767,
#   'Anthony Brown',
#   'ellisalejandro@sloan-gardner.biz',
#   '992 Henry Centers Apt. 571',
#   'Mcintoshport',
#   'Manitoba',
#   'Montenegro',
#   '1 (778) 016-3803',
#   'Minima at officiis tenetur quas possimus.',
#   '2021-10-24',
#   1101,
#   '2022-02-17 22:15:41.631729',
#   '2022-02-17 22:15:41.631731',
#   '114.246.225.186'),
#  (768,
#   'Kaitlyn Best',
#   'sweeneymichael@yahoo.com',
#   '1789 Tucker Lake',
#   'Jamesside',
#   'Northwest Territories',
#   'Kyrgyz Republic',
#   '(251) 326-5352 x740',
#   'Dignissimos quos consequuntur magni deleniti sed dolorem dolor.',
#   '1907-02-23',
#   1532,
#   '2022-02-17 22:15:41.632507',
#   '2022-02-17 22:15:41.632508',
#   '188.131.152.205'),
#  (769,
#   'Maurice Webb',
#   'matthewjones@yahoo.com',
#   '16425 Francisco Freeway',
#   'Wesleyland',
#   'Nunavut',
#   'Saudi Arabia',
#   '797-654-8709',
#   'Ex omnis ad assumenda nobis ab rem.',
#   '1941-10-24',
#   2058,
#   '2022-02-17 22:15:41.633250',
#   '2022-02-17 22:15:41.633251',
#   '213.148.92.242'),
#  (770,
#   'Shawn Martin',
#   'nnguyen@yahoo.com',
#   '855 Chad Expressway',
#   'South Lisamouth',
#   'British Columbia',
#   'Lebanon',
#   '538-227-8000 x285',
#   'Deleniti veniam voluptatibus nobis facere.',
#   '1988-09-16',
#   1196,
#   '2022-02-17 22:15:41.633979',
#   '2022-02-17 22:15:41.633981',
#   '203.68.37.164'),
#  (771,
#   'Christopher Cantrell',
#   'austinmatthew@davis.info',
#   '125 Shaw Radial',
#   'Laurachester',
#   'Quebec',
#   'Spain',
#   '889 499 1603',
#   'Ratione ipsum ad dolores corrupti temporibus natus omnis.',
#   '2012-09-24',
#   2019,
#   '2022-02-17 22:15:41.635033',
#   '2022-02-17 22:15:41.635035',
#   '182.111.228.69'),
#  (772,
#   'Cameron Levy',
#   'beth34@gmail.com',
#   '461 Hughes Oval',
#   'West Martha',
#   'Ontario',
#   'Kiribati',
#   '601-252-4421',
#   'Voluptatibus nam facilis harum molestiae quisquam atque quasi.',
#   '1967-01-11',
#   2053,
#   '2022-02-17 22:15:41.635731',
#   '2022-02-17 22:15:41.635733',
#   '120.195.255.15'),
#  (773,
#   'Angela Perez',
#   'griffithvincent@meadows.net',
#   '679 White Port',
#   'South Nicholas',
#   'Saskatchewan',
#   'Haiti',
#   '291 970 8127',
#   'Repellendus adipisci facere ducimus vero.',
#   '1955-10-02',
#   2112,
#   '2022-02-17 22:15:41.636592',
#   '2022-02-17 22:15:41.636594',
#   '98.174.143.26'),
#  (774,
#   'April Jones',
#   'cmccarthy@wright.com',
#   '9697 Jensen Radial Apt. 840',
#   'South Kennethmouth',
#   'Alberta',
#   'British Indian Ocean Territory (Chagos Archipelago)',
#   '696.460.6403',
#   'Exercitationem maxime soluta illo aliquid ducimus consequuntur.',
#   '1908-07-28',
#   1615,
#   '2022-02-17 22:15:41.637589',
#   '2022-02-17 22:15:41.637591',
#   '142.7.97.192'),
#  (775,
#   'Heidi Thomas',
#   'bobby22@barnett.biz',
#   '7956 Raymond Inlet',
#   'North Danny',
#   'Ontario',
#   'Anguilla',
#   '1-986-976-6418',
#   'Voluptatem aliquam illum sint odit esse fugit.',
#   '1939-04-09',
#   1922,
#   '2022-02-17 22:15:41.638528',
#   '2022-02-17 22:15:41.638530',
#   '180.208.134.167'),
#  (776,
#   'Justin Cook',
#   'lindseyvalenzuela@gmail.com',
#   '50004 Matthew Burg',
#   'Parksberg',
#   'Prince Edward Island',
#   'Australia',
#   '+1 (617) 754-8535',
#   'In similique fugiat quisquam ipsum ullam suscipit.',
#   '1947-03-20',
#   2462,
#   '2022-02-17 22:15:41.639292',
#   '2022-02-17 22:15:41.639293',
#   '33.127.84.153'),
#  (777,
#   'Casey Mccormick',
#   'williamsadrian@ballard.biz',
#   '3174 Rachel Harbor Apt. 329',
#   'Michaelland',
#   'Ontario',
#   'Guinea-Bissau',
#   '+1 (901) 694-4628',
#   'Iure aut quia molestiae neque.',
#   '2000-10-24',
#   1120,
#   '2022-02-17 22:15:41.640159',
#   '2022-02-17 22:15:41.640161',
#   '197.72.120.220'),
#  (778,
#   'Charles Palmer',
#   'james38@gmail.com',
#   '41739 Lara Lodge Suite 380',
#   'Judyport',
#   'Northwest Territories',
#   'Bahrain',
#   '802.465.2363',
#   'Repellendus minus nisi aliquam beatae accusantium praesentium sint '
#   'reprehenderit.',
#   '1971-03-25',
#   1782,
#   '2022-02-17 22:15:41.640863',
#   '2022-02-17 22:15:41.640865',
#   '207.16.215.217'),
#  (779,
#   'Christine Smith',
#   'anna18@arias-brown.com',
#   '28073 Colton Prairie',
#   'Aaronport',
#   'Newfoundland and Labrador',
#   'Egypt',
#   '901 157 8991',
#   'Eos dicta optio nisi harum eum vero fugit rem nulla.',
#   '1955-02-19',
#   1979,
#   '2022-02-17 22:15:41.641732',
#   '2022-02-17 22:15:41.641734',
#   '212.12.51.126'),
#  (780,
#   'Kyle Mcfarland',
#   'zcruz@gmail.com',
#   '89270 Adam Ridge',
#   'West Christopherhaven',
#   'Ontario',
#   'Poland',
#   '1 (726) 200-2396',
#   'Officiis libero distinctio ipsam error aperiam.',
#   '1935-12-02',
#   2428,
#   '2022-02-17 22:15:41.642426',
#   '2022-02-17 22:15:41.642427',
#   '157.67.119.103'),
#  (781,
#   'Angela Holmes',
#   'pmoon@yahoo.com',
#   '29686 Kendra Lights Suite 130',
#   'Nelsonhaven',
#   'Northwest Territories',
#   'Kazakhstan',
#   '+1 (728) 597-9431',
#   'Eius commodi quidem dolorem ea dignissimos repellat amet modi perferendis.',
#   '1962-07-16',
#   2484,
#   '2022-02-17 22:15:41.643143',
#   '2022-02-17 22:15:41.643144',
#   '144.191.89.93'),
#  (782,
#   'Lisa Mills',
#   'dakota20@fernandez-burns.biz',
#   '5915 Mason Radial Suite 664',
#   'Lake Andrewfort',
#   'Newfoundland and Labrador',
#   'Greenland',
#   '(490) 636-9911',
#   'Illo repudiandae illum dolores amet nisi fuga assumenda dicta.',
#   '1945-02-23',
#   2442,
#   '2022-02-17 22:15:41.644032',
#   '2022-02-17 22:15:41.644033',
#   '181.80.75.19'),
#  (783,
#   'Angela Harris',
#   'brianna97@price.com',
#   '3839 Kristina Plaza Suite 476',
#   'Sharonstad',
#   'Quebec',
#   'Cayman Islands',
#   '588 493 9113',
#   'Omnis earum maiores quae molestiae blanditiis veritatis.',
#   '1925-10-22',
#   1850,
#   '2022-02-17 22:15:41.644993',
#   '2022-02-17 22:15:41.644995',
#   '16.54.116.223'),
#  (784,
#   'Vanessa Campbell',
#   'jennifer14@gmail.com',
#   '895 Colleen Causeway Apt. 152',
#   'North Andrew',
#   'New Brunswick',
#   'Palestinian Territory',
#   '743-746-2055',
#   'Temporibus aliquam repellendus occaecati ipsum quaerat nisi.',
#   '1909-05-02',
#   1950,
#   '2022-02-17 22:15:41.645798',
#   '2022-02-17 22:15:41.645800',
#   '198.242.178.78'),
#  (785,
#   'Karen Lopez',
#   'gillespieshane@gmail.com',
#   '979 Grant Wall Apt. 658',
#   'West Melissaside',
#   'Yukon Territory',
#   'Sao Tome and Principe',
#   '642-016-8427 x559',
#   'Quis libero quisquam ad facere.',
#   '1931-10-16',
#   2451,
#   '2022-02-17 22:15:41.646577',
#   '2022-02-17 22:15:41.646579',
#   '165.83.8.218'),
#  (786,
#   'John Stephens',
#   'khowell@harvey.com',
#   '7399 Christine Canyon Apt. 810',
#   'South Beth',
#   'Newfoundland and Labrador',
#   'Aruba',
#   '870 204 6264',
#   'Praesentium distinctio molestias nostrum et repellendus.',
#   '1978-04-07',
#   1663,
#   '2022-02-17 22:15:41.647545',
#   '2022-02-17 22:15:41.647547',
#   '41.16.144.129'),
#  (787,
#   'Christina Gonzales',
#   'xramirez@erickson.com',
#   '104 Casey Trace',
#   'West Rachel',
#   'Nova Scotia',
#   'Yemen',
#   '1-805-341-1146',
#   'Porro optio ducimus optio labore vel et dolores iste.',
#   '1933-11-16',
#   2392,
#   '2022-02-17 22:15:41.648496',
#   '2022-02-17 22:15:41.648497',
#   '171.251.179.6'),
#  (788,
#   'Amy Smith',
#   'becky93@hotmail.com',
#   '5284 Mary Glens',
#   'Drakestad',
#   'Northwest Territories',
#   'Anguilla',
#   '(695) 324-4748 x651',
#   'Natus doloribus nemo quaerat saepe similique quasi repellat voluptate.',
#   '1989-07-28',
#   1733,
#   '2022-02-17 22:15:41.649184',
#   '2022-02-17 22:15:41.649185',
#   '219.252.211.168'),
#  (789,
#   'Ashley Smith',
#   'ayalalarry@gmail.com',
#   '82154 Arellano Rue Suite 329',
#   'West Brandifurt',
#   'New Brunswick',
#   'Chile',
#   '114-912-0839',
#   'Cumque a facere quae nihil nihil non.',
#   '1939-06-09',
#   1627,
#   '2022-02-17 22:15:41.649968',
#   '2022-02-17 22:15:41.649969',
#   '79.125.199.142'),
#  (790,
#   'Jason Jenkins',
#   'troystephens@williams.net',
#   '95179 David Manors',
#   'Fowlerburgh',
#   'Ontario',
#   'Bahrain',
#   '931 549 5002',
#   'Magni natus odit explicabo error ipsa quos amet hic.',
#   '2005-03-11',
#   1676,
#   '2022-02-17 22:15:41.650994',
#   '2022-02-17 22:15:41.650995',
#   '214.80.193.100'),
#  (791,
#   'Ariel Gonzalez',
#   'murraykristin@ramirez.com',
#   '7163 Robinson Locks Suite 956',
#   'Tonyaborough',
#   'Manitoba',
#   'Montenegro',
#   '1 (896) 072-4409',
#   'Repudiandae laboriosam corporis magni veritatis maiores sapiente adipisci '
#   'quae fuga.',
#   '2003-06-17',
#   1335,
#   '2022-02-17 22:15:41.652038',
#   '2022-02-17 22:15:41.652040',
#   '23.111.153.71'),
#  (792,
#   'Kristina Barber',
#   'bryanpope@hotmail.com',
#   '146 Hogan Walks',
#   'Brettton',
#   'Manitoba',
#   'Namibia',
#   '832.454.2910',
#   'Odio saepe animi alias voluptatum id doloribus.',
#   '2021-11-12',
#   2258,
#   '2022-02-17 22:15:41.652813',
#   '2022-02-17 22:15:41.652815',
#   '14.54.151.116'),
#  (793,
#   'Adam Thomas',
#   'joshua32@bishop.com',
#   '5304 Monica Road',
#   'North Juan',
#   'Newfoundland and Labrador',
#   'Madagascar',
#   '1-180-308-7389',
#   'Earum soluta error sunt ea reprehenderit aliquid libero quibusdam porro.',
#   '1951-05-26',
#   1204,
#   '2022-02-17 22:15:41.653592',
#   '2022-02-17 22:15:41.653594',
#   '88.53.53.5'),
#  (794,
#   'Frederick Mitchell',
#   'jennifermclaughlin@hotmail.com',
#   '68618 Stephens Summit Suite 116',
#   'East Tonyside',
#   'New Brunswick',
#   'Macedonia',
#   '528-623-2937 x080',
#   'Temporibus dolore placeat velit pariatur fugiat atque commodi.',
#   '2014-06-16',
#   1364,
#   '2022-02-17 22:15:41.654523',
#   '2022-02-17 22:15:41.654525',
#   '151.55.3.209'),
#  (795,
# ...
#   'Port Josephbury',
#   'Prince Edward Island',
#   'Swaziland',
#   '522-731-1668',
#   'Sapiente voluptatibus optio veritatis repellendus aliquid.',
#   '1997-04-17',
#   1529,
#   '2022-02-17 22:15:41.811638',
#   '2022-02-17 22:15:41.811640',
#   '219.189.232.254'),
#  (955,
#   'Charles Ware',
#   'matthew14@owens-morales.com',
#   '272 William Springs',
#   'South Johnmouth',
#   'Prince Edward Island',
#   'Philippines',
#   '813 911 4849',
#   'Ad earum soluta sapiente reiciendis doloribus.',
#   '1913-09-14',
#   1899,
#   '2022-02-17 22:15:41.812492',
#   '2022-02-17 22:15:41.812493',
#   '8.104.20.141'),
#  (956,
#   'Mary White',
#   'george00@hotmail.com',
#   '226 Tiffany Expressway Apt. 771',
#   'Lake Stevenmouth',
#   'Prince Edward Island',
#   'Somalia',
#   '1-855-232-8437',
#   'Occaecati quasi maiores modi iste porro sint.',
#   '1994-03-14',
#   2362,
#   '2022-02-17 22:15:41.813163',
#   '2022-02-17 22:15:41.813165',
#   '157.11.233.91'),
#  (957,
#   'Eric Sexton',
#   'tammy46@foster.com',
#   '30059 Bailey Path Suite 525',
#   'Andradestad',
#   'Quebec',
#   'Cameroon',
#   '512 840 0714',
#   'Beatae eius dolorum natus incidunt.',
#   '1928-07-28',
#   1109,
#   '2022-02-17 22:15:41.814027',
#   '2022-02-17 22:15:41.814029',
#   '132.3.124.179'),
#  (958,
#   'Tiffany Blanchard',
#   'seanmanning@lucero.com',
#   '953 Jackson Pass Suite 170',
#   'Sarahton',
#   'Newfoundland and Labrador',
#   'Jamaica',
#   '(862) 162-6727 x384',
#   'Totam natus dignissimos sequi blanditiis a sint.',
#   '1928-09-06',
#   2396,
#   '2022-02-17 22:15:41.815074',
#   '2022-02-17 22:15:41.815085',
#   '162.248.214.122'),
#  (959,
#   'Kimberly Rose',
#   'carriethomas@hotmail.com',
#   '57525 Scott Lodge',
#   'Michaelchester',
#   'Newfoundland and Labrador',
#   'El Salvador',
#   '243-195-9566',
#   'Dolorum modi neque odio inventore neque tempora pariatur.',
#   '1907-04-11',
#   2253,
#   '2022-02-17 22:15:41.815861',
#   '2022-02-17 22:15:41.815863',
#   '139.173.206.143'),
#  (960,
#   'Curtis Miller',
#   'paige75@yahoo.com',
#   '9606 David Manor Suite 839',
#   'Lake Todd',
#   'Prince Edward Island',
#   'Suriname',
#   '896-805-8230',
#   'Nisi corrupti praesentium dicta sapiente totam repellat quas.',
#   '2011-03-06',
#   2394,
#   '2022-02-17 22:15:41.816547',
#   '2022-02-17 22:15:41.816548',
#   '55.192.26.223'),
#  (961,
#   'Samantha Cruz',
#   'harry16@wright-ritter.com',
#   '082 Dustin Isle',
#   'Whiteheadchester',
#   'Yukon Territory',
#   'Liechtenstein',
#   '(576) 649-4770 x648',
#   'Esse minus quis omnis debitis tenetur a molestias.',
#   '1962-11-10',
#   1884,
#   '2022-02-17 22:15:41.817435',
#   '2022-02-17 22:15:41.817436',
#   '180.104.92.248'),
#  (962,
#   'Julie Bartlett',
#   'shirleyrodgers@garcia.org',
#   '57023 Brown Viaduct Apt. 066',
#   'Lonniemouth',
#   'British Columbia',
#   'Jersey',
#   '(682) 119-3124 x320',
#   'Facere quis facilis quidem sint voluptate hic ratione.',
#   '2015-04-07',
#   1363,
#   '2022-02-17 22:15:41.818330',
#   '2022-02-17 22:15:41.818332',
#   '200.180.190.78'),
#  (963,
#   'Sarah Vega',
#   'johnsontonya@lopez.com',
#   '40783 David Forge Apt. 495',
#   'North Abigail',
#   'British Columbia',
#   'Bahrain',
#   '1 (733) 220-1597',
#   'Perspiciatis fugit dignissimos error molestiae.',
#   '1913-08-20',
#   2187,
#   '2022-02-17 22:15:41.819185',
#   '2022-02-17 22:15:41.819187',
#   '61.151.170.94'),
#  (964,
#   'Melanie Mitchell',
#   'russellbrittany@hotmail.com',
#   '839 Raymond Trail',
#   'East Cheryl',
#   'Quebec',
#   'Nigeria',
#   '(639) 054-1707',
#   'Debitis velit blanditiis id incidunt quam magni cupiditate laudantium '
#   'autem.',
#   '2021-07-17',
#   1593,
#   '2022-02-17 22:15:41.819925',
#   '2022-02-17 22:15:41.819927',
#   '129.200.255.55'),
#  (965,
#   'Peter Hampton',
#   'skent@smith-cain.com',
#   '0958 Miller Streets',
#   'West Petermouth',
#   'Prince Edward Island',
#   'Marshall Islands',
#   '(871) 973-0245',
#   'Cupiditate impedit saepe eaque sit sapiente.',
#   '1986-09-10',
#   1472,
#   '2022-02-17 22:15:41.820815',
#   '2022-02-17 22:15:41.820816',
#   '5.245.111.164'),
#  (966,
#   'Michael Bennett',
#   'smithpaige@parker.com',
#   '3349 Sydney Hills',
#   'North Jose',
#   'Ontario',
#   'Lithuania',
#   '(421) 600-0643',
#   'Necessitatibus atque pariatur unde dolorum eveniet saepe tenetur.',
#   '1969-06-03',
#   1413,
#   '2022-02-17 22:15:41.821856',
#   '2022-02-17 22:15:41.821857',
#   '104.50.213.30'),
#  (967,
#   'Katie Robinson',
#   'noah46@oconnell.com',
#   '7317 Jordan Mill',
#   'Cooperfort',
#   'Nunavut',
#   'Palau',
#   '725-740-3930 x390',
#   'Quam blanditiis reiciendis culpa in repudiandae aliquam magni esse.',
#   '1927-12-20',
#   1104,
#   '2022-02-17 22:15:41.822864',
#   '2022-02-17 22:15:41.822865',
#   '140.59.184.84'),
#  (968,
#   'John Gonzalez',
#   'psmith@sosa-hutchinson.info',
#   '96657 Ortega Squares Suite 837',
#   'Baileystad',
#   'Alberta',
#   'Papua New Guinea',
#   '+1 (835) 794-7545',
#   'Dolores dolor labore accusamus repudiandae.',
#   '1975-09-09',
#   1644,
#   '2022-02-17 22:15:41.823804',
#   '2022-02-17 22:15:41.823806',
#   '33.122.195.81'),
#  (969,
#   'Alejandro Wright',
#   'golson@yahoo.com',
#   '07412 Price Burg Suite 411',
#   'West Monica',
#   'Prince Edward Island',
#   'Hong Kong',
#   '1-682-936-4772',
#   'Tenetur dolorum fugiat sint facere dolorum.',
#   '1932-06-14',
#   1298,
#   '2022-02-17 22:15:41.824544',
#   '2022-02-17 22:15:41.824546',
#   '156.27.159.56'),
#  (970,
#   'Cindy Reyes',
#   'stonedanielle@fry-richardson.com',
#   '13928 Ashley Street',
#   'East Annaport',
#   'Manitoba',
#   'Nigeria',
#   '392-203-5590',
#   'Placeat in temporibus fugit quae cumque voluptatem rem.',
#   '1980-08-20',
#   2453,
#   '2022-02-17 22:15:41.825600',
#   '2022-02-17 22:15:41.825602',
#   '98.202.255.64'),
#  (971,
#   'Tyler Bell',
#   'lisa57@yahoo.com',
#   '626 Lisa Hills',
#   'West Cynthiatown',
#   'Saskatchewan',
#   'Azerbaijan',
#   '680 454 0061',
#   'Fuga totam ullam rerum et culpa omnis quaerat.',
#   '2018-09-18',
#   1485,
#   '2022-02-17 22:15:41.826291',
#   '2022-02-17 22:15:41.826293',
#   '122.204.85.156'),
#  (972,
#   'Jessica George',
#   'brandoncarney@yahoo.com',
#   '999 Stephanie Ford',
#   'Port Wesley',
#   'Manitoba',
#   'United Kingdom',
#   '312.057.8436',
#   'Qui temporibus porro ratione ea.',
#   '1908-03-02',
#   1574,
#   '2022-02-17 22:15:41.827087',
#   '2022-02-17 22:15:41.827088',
#   '28.163.163.168'),
#  (973,
#   'Shannon Harris',
#   'brittanychan@brown-li.org',
#   '96926 Mary Knoll',
#   'North Thomas',
#   'New Brunswick',
#   'Saint Vincent and the Grenadines',
#   '(512) 519-5836 x707',
#   'Sed animi harum doloremque aliquid.',
#   '1914-12-30',
#   2367,
#   '2022-02-17 22:15:41.828378',
#   '2022-02-17 22:15:41.828379',
#   '76.96.125.249'),
#  (974,
#   'Kelly Greer',
#   'mccoyandrew@lewis.org',
#   '95696 Butler Rapids',
#   'Jordanstad',
#   'Quebec',
#   'Kiribati',
#   '1-693-436-0867',
#   'Quidem optio repellat optio illum libero esse vel sed autem.',
#   '1961-11-01',
#   2126,
#   '2022-02-17 22:15:41.829418',
#   '2022-02-17 22:15:41.829420',
#   '142.104.234.206'),
#  (975,
#   'Timothy Erickson',
#   'grant23@hotmail.com',
#   '49772 Margaret Pike Suite 226',
#   'Joshuafort',
#   'Prince Edward Island',
#   'Antarctica (the territory South of 60 deg S)',
#   '(460) 443-7059',
#   'Veritatis debitis tenetur delectus atque esse.',
#   '1983-04-29',
#   1839,
#   '2022-02-17 22:15:41.830117',
#   '2022-02-17 22:15:41.830119',
#   '37.44.155.190'),
#  (976,
#   'Alexander Hudson',
#   'riverarichard@davis.com',
#   '43076 Noah Lock',
#   'Martinberg',
#   'Quebec',
#   'Greenland',
#   '124-488-7451',
#   'Pariatur temporibus animi consequatur dolorum expedita ab nulla fuga dolore '
#   'iusto.',
#   '1924-10-01',
#   2361,
#   '2022-02-17 22:15:41.831131',
#   '2022-02-17 22:15:41.831132',
#   '222.186.235.125'),
#  (977,
#   'Paul Evans',
#   'angela08@gmail.com',
#   '8221 Wilson Knoll Suite 699',
#   'Port Carlborough',
#   'Nunavut',
#   'American Samoa',
#   '1 (814) 775-0214',
#   'Neque reiciendis culpa sequi culpa modi placeat praesentium.',
#   '1937-06-06',
#   1979,
#   '2022-02-17 22:15:41.831845',
#   '2022-02-17 22:15:41.831847',
#   '153.254.125.125'),
#  (978,
#   'William Medina',
#   'lgarcia@wright.com',
#   '03581 Sutton Ford',
#   'Judithburgh',
#   'Ontario',
#   'Jordan',
#   '153 641 9394',
#   'Consectetur molestiae laudantium cupiditate iure sed nisi cum.',
#   '1939-05-27',
#   1826,
#   '2022-02-17 22:15:41.833036',
#   '2022-02-17 22:15:41.833039',
#   '199.201.248.215'),
#  (979,
#   'John Brown',
#   'imay@henderson.com',
#   '92114 Potts Valleys',
#   'Johnsonside',
#   'Nunavut',
#   'Cook Islands',
#   '295.379.9499',
#   'Veniam repellat reprehenderit ut nobis sed occaecati.',
#   '1971-10-23',
#   1849,
#   '2022-02-17 22:15:41.834219',
#   '2022-02-17 22:15:41.834221',
#   '85.23.202.183'),
#  (980,
#   'Kelsey Reese',
#   'ptaylor@gmail.com',
#   '896 Stewart View',
#   'Jessicafurt',
#   'Newfoundland and Labrador',
#   'South Africa',
#   '317 055 7957',
#   'Accusantium autem esse expedita ut ipsa expedita.',
#   '1912-08-07',
#   1820,
#   '2022-02-17 22:15:41.834950',
#   '2022-02-17 22:15:41.834952',
#   '153.187.182.149'),
#  (981,
#   'Sarah Brown',
#   'cward@lopez-shaw.biz',
#   '9609 Mccormick Dale Apt. 660',
#   'Alexandraside',
#   'Nunavut',
#   'Barbados',
#   '669.460.0225',
#   'Occaecati maiores odio id iure.',
#   '1932-01-21',
#   1664,
#   '2022-02-17 22:15:41.835865',
#   '2022-02-17 22:15:41.835866',
#   '186.9.15.252'),
#  (982,
#   'Jessica Kramer',
#   'wmontes@gmail.com',
#   '61642 Gerald Burgs',
#   'Johnshire',
#   'New Brunswick',
#   'Guernsey',
#   '+1 (577) 150-3925',
#   'Laboriosam asperiores delectus reiciendis asperiores minima velit quasi '
#   'accusamus assumenda.',
#   '2008-07-02',
#   1173,
#   '2022-02-17 22:15:41.836572',
#   '2022-02-17 22:15:41.836574',
#   '221.186.114.31'),
#  (983,
#   'Kevin Thornton',
#   'david75@martin.net',
#   '63509 Larry Divide Apt. 731',
#   'Port Ana',
#   'Alberta',
#   'Singapore',
#   '848 603 1296',
#   'Velit velit nostrum perspiciatis quis cum omnis deserunt unde odio.',
#   '1955-10-10',
#   2255,
#   '2022-02-17 22:15:41.837577',
#   '2022-02-17 22:15:41.837579',
#   '65.132.222.215'),
#  (984,
#   'Amber Lopez DDS',
#   'willisjohn@hotmail.com',
#   '3788 Bell Villages Apt. 010',
#   'Briantown',
#   'Quebec',
#   'Indonesia',
#   '323-426-3358',
#   'Officia aliquid facere aperiam vitae magni debitis itaque suscipit hic.',
#   '1910-01-13',
#   2496,
#   '2022-02-17 22:15:41.838389',
#   '2022-02-17 22:15:41.838390',
#   '202.63.151.166'),
#  (985,
#   'Linda Scott',
#   'beckerjulie@andrews.com',
#   '447 William Mission Suite 697',
#   'Millsside',
#   'Nova Scotia',
#   'Montserrat',
#   '531-134-9625',
#   'Vitae totam dolor consequatur fugit labore inventore.',
#   '1939-03-21',
#   1390,
#   '2022-02-17 22:15:41.839425',
#   '2022-02-17 22:15:41.839426',
#   '118.174.12.239'),
#  (986,
#   'Michelle Delgado',
#   'estradakenneth@martin-hunt.com',
#   '6079 Lisa Locks',
#   'New Shelbyfurt',
#   'Ontario',
#   'Liechtenstein',
#   '378.995.4427',
#   'Libero sit esse recusandae doloremque exercitationem blanditiis voluptatum.',
#   '1957-08-17',
#   1987,
#   '2022-02-17 22:15:41.840353',
#   '2022-02-17 22:15:41.840355',
#   '212.250.254.223'),
#  (987,
#   'David Meyer',
#   'shawncook@wilkinson.com',
#   '188 Dustin Falls',
#   'Millershire',
#   'Manitoba',
#   'Barbados',
#   '661-190-6066 x271',
#   'Ex quo dolores voluptate hic exercitationem.',
#   '1912-09-07',
#   1806,
#   '2022-02-17 22:15:41.841213',
#   '2022-02-17 22:15:41.841215',
#   '205.220.166.76'),
#  (988,
#   'Dwayne Johnson',
#   'eharper@hotmail.com',
#   '16465 Smith Pike Suite 846',
#   'Lake Veronicahaven',
#   'Alberta',
#   'Barbados',
#   '916-438-0423',
#   'Libero eveniet sapiente id sapiente blanditiis.',
#   '1913-01-29',
#   1029,
#   '2022-02-17 22:15:41.841942',
#   '2022-02-17 22:15:41.841943',
#   '151.71.187.254'),
#  (989,
#   'Dakota Hansen',
#   'baldwinchristina@moreno-rocha.biz',
#   '6917 Dean Vista',
#   'Port Wendy',
#   'British Columbia',
#   'Spain',
#   '914.323.9505',
#   'Culpa earum deserunt enim ab iure porro aliquam veritatis quia.',
#   '1927-09-30',
#   1944,
#   '2022-02-17 22:15:41.842888',
#   '2022-02-17 22:15:41.842889',
#   '60.84.46.249'),
#  (990,
#   'Richard Morris',
#   'walkertravis@hotmail.com',
#   '9595 Davis Locks',
#   'West Susanton',
#   'Saskatchewan',
#   'Ecuador',
#   '907 500 5075',
#   'Fuga voluptates suscipit repudiandae suscipit veniam velit cupiditate.',
#   '2021-12-21',
#   2156,
#   '2022-02-17 22:15:41.843660',
#   '2022-02-17 22:15:41.843662',
#   '213.168.220.54'),
#  (991,
#   'Beth Taylor',
#   'brianfowler@hensley-johnson.net',
#   '498 Russell Extension',
#   'Johnsonmouth',
#   'Saskatchewan',
#   'Armenia',
#   '761-858-4316 x347',
#   'Eveniet possimus deserunt temporibus veritatis explicabo nostrum quis.',
#   '1946-06-28',
#   1859,
#   '2022-02-17 22:15:41.844644',
#   '2022-02-17 22:15:41.844646',
#   '101.216.79.19'),
#  (992,
#   'Clayton Wong',
#   'kwilliams@powers.com',
#   '615 Glenn Prairie',
#   'West Daniel',
#   'New Brunswick',
#   'Antigua and Barbuda',
#   '+1 (875) 010-4123',
#   'Tempore eaque animi similique consectetur officia cupiditate ad.',
#   '1919-04-20',
#   1038,
#   '2022-02-17 22:15:41.845511',
#   '2022-02-17 22:15:41.845513',
#   '99.222.242.161'),
#  (993,
#   'Tony Maddox',
#   'ryanelizabeth@navarro.biz',
#   '66241 Parks Crossing',
#   'Kimberlyville',
#   'Northwest Territories',
#   'Swaziland',
#   '1 (146) 935-2267',
#   'Excepturi eaque aut dicta reprehenderit sed voluptatum fugit reiciendis '
#   'architecto.',
#   '1933-11-28',
#   1258,
#   '2022-02-17 22:15:41.846399',
#   '2022-02-17 22:15:41.846401',
#   '173.235.185.10'),
#  (994,
#   'Brianna Johnson',
#   'jerrywatkins@hotmail.com',
#   '51131 Joseph Pine',
#   'Sarahborough',
#   'New Brunswick',
#   'Namibia',
#   '1 (353) 858-8168',
#   'Magni omnis officia quam animi qui minus deleniti accusamus.',
#   '1936-07-18',
#   2188,
#   '2022-02-17 22:15:41.847138',
#   '2022-02-17 22:15:41.847139',
#   '172.59.97.92'),
#  (995,
#   'Lauren Garcia',
#   'laura49@wilcox.com',
#   '37081 Nathan Mountain Suite 445',
#   'West Cameron',
#   'British Columbia',
#   'Luxembourg',
#   '817.258.6130',
#   'Corporis maiores accusantium blanditiis delectus veniam vel veniam beatae '
#   'consequatur voluptate.',
#   '1927-03-24',
#   1096,
#   '2022-02-17 22:15:41.847920',
#   '2022-02-17 22:15:41.847921',
#   '34.209.0.6'),
#  (996,
#   'Erin Clay',
#   'lwright@wilson.biz',
#   '12835 Rice Prairie Apt. 369',
#   'North Eric',
#   'Manitoba',
#   'Norfolk Island',
#   '+1 (641) 269-8582',
#   'Distinctio aliquam molestiae veniam nulla.',
#   '1920-05-05',
#   1644,
#   '2022-02-17 22:15:41.848755',
#   '2022-02-17 22:15:41.848757',
#   '138.113.108.166'),
#  (997,
#   'Benjamin Carroll Jr.',
#   'courtneymorton@davis-williams.com',
#   '7350 Jon Cliff Suite 395',
#   'Thomasview',
#   'Manitoba',
#   'Falkland Islands (Malvinas)',
#   '725.891.5393',
#   'Natus minima nihil amet incidunt ad autem.',
#   '1972-02-02',
#   2035,
#   '2022-02-17 22:15:41.849718',
#   '2022-02-17 22:15:41.849720',
#   '44.103.20.103'),
#  (998,
#   'Timothy Smith',
#   'angelapowell@yahoo.com',
#   '4541 Timothy Rest',
#   'North Jamesbury',
#   'Nunavut',
#   'Mauritius',
#   '836.541.8369',
#   'Quas esse explicabo inventore eum aliquid impedit.',
#   '1999-08-25',
#   1361,
#   '2022-02-17 22:15:41.850478',
#   '2022-02-17 22:15:41.850479',
#   '146.75.179.121'),
#  (999,
#   'Andrew Wright',
#   'nicholas37@hotmail.com',
#   '61878 Pittman Camp Apt. 936',
#   'Anthonyshire',
#   'Saskatchewan',
#   'Libyan Arab Jamahiriya',
#   '(925) 147-1881 x665',
#   'Molestiae natus pariatur reprehenderit cupiditate.',
#   '2020-01-08',
#   1211,
#   '2022-02-17 22:15:41.851176',
#   '2022-02-17 22:15:41.851178',
#   '222.132.181.96'),
#  (1000,
#   'Summer Smith',
#   'charles02@lopez-berg.com',
#   '8064 Olivia Way',
#   'South Henry',
#   'Manitoba',
#   'Bahamas',
#   '158.757.9648',
#   'Tenetur unde occaecati incidunt neque numquam assumenda molestias.',
#   '1945-05-31',
#   2339,
#   '2022-02-17 22:15:41.852017',
#   '2022-02-17 22:15:41.852019',
#   '70.242.15.30'),
#  (1001,
#   'Justin Cross',
#   'lopezwilliam@perez.com',
#   '9531 Garcia Expressway',
#   'Lake Benjaminberg',
#   'Northwest Territories',
#   'Bosnia and Herzegovina',
#   '478.905.4980',
#   'Porro voluptates sed qui dolore alias.',
#   '2010-06-25',
#   1743,
#   '2022-02-17 22:15:41.853039',
#   '2022-02-17 22:15:41.853040',
#   '126.138.51.38'),
#  (1002,
#   'Mary Walker',
#   'meganolson@hotmail.com',
#   '698 Beltran Loop',
#   'West Valerie',
#   'Newfoundland and Labrador',
#   'Antarctica (the territory South of 60 deg S)',
#   '893-134-9757 x909',
#   'Corporis esse voluptates deserunt animi quia autem tempore.',
#   '1913-03-27',
#   1112,
#   '2022-02-17 22:15:41.853822',
#   '2022-02-17 22:15:41.853824',
#   '162.226.218.50')]

# %% [markdown]
# Finally, the last step,
# Using the code block below, combined with what you have learned above, and the Lecture notes,
# Craft a SQL Query that will return the `name` of no more than `20` `people` with a `heatmap` greater than `1500`

# %%
import sqlite3 #making sqlite3 available for use, to communicate with our database
import pprint #Outputs data in a slightly easier to read format

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#query to get the names of the people with heatmaps greater than 1500, limited to 20
selectStatement = """SELECT name FROM people
                      WHERE heatmap > 1500
                      LIMIT 20"""

myCursor.execute(selectStatement) #runs the query
results = myCursor.fetchall() #gets all the output of the query
pprint.pprint(results) #shows the output in a nicer way

myConnection.close()#closes the connection
# Out:
# [('Tonya Young',),
#  ('Gina Mann',),
#  ('Melissa Wright',),
#  ('Ashley Guerrero',),
#  ('Todd Mendez',),
#  ('David Smith',),
#  ('Barbara Rojas',),
#  ('Lisa West',),
#  ('Selena Graham',),
#  ('Jennifer Curtis',),
#  ('Alvin Williams',),
#  ('Michael Armstrong',),
#  ('Steven Smith',),
#  ('Leslie Mcneil',),
#  ('Michael Alexander',),
#  ('Susan Russell',),
#  ('Kristina Curtis',),
#  ('Mark Williams',),
#  ('Nicole Thomas',),
#  ('Phillip Moore',)]

# %% [markdown]
# Your submission will contain, as usual, a link to your completed colab notebook, but in addition to that, you will download a copy of your social_network.db file and upload it to D2L. To download the file, right click it from the Files menu on the left of the Notebook.
